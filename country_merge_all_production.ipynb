# %%
# =============================================================================
# CELL 1: Configuration and Imports
# =============================================================================
import pandas as pd
import numpy as np
import os
import gc
import time
import warnings
from datetime import datetime

# Suppress fragmentation warning (cosmetic - doesn't affect correctness)
warnings.filterwarnings('ignore', message='DataFrame is highly fragmented')

# Input: merged pool files from full_universe_merge
INPUT_DIR = r"D:\ECB_ESMA_MERGED"

# Output: NEW folder for all country files
OUTPUT_DIR = r"D:\ECB_ESMA_BY_COUNTRY_ALL"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Chunk size for memory-efficient processing
CHUNK_SIZE = 100000

print(f"Input directory: {INPUT_DIR}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Chunk size: {CHUNK_SIZE:,} rows")
print()
print(f"Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Input directory: D:\ECB_ESMA_MERGED
# Output directory: D:\ECB_ESMA_BY_COUNTRY_ALL
# Chunk size: 100,000 rows
#
# Started at: 2025-12-12 22:27:19

# %%
# =============================================================================
# CELL 2: Country Detection Function (VERIFIED - DO NOT MODIFY)
# =============================================================================
def detect_country(df, pool_id):
    """
    Detect country from file data or pool ID.
    Priority order:
    1. RREL81 (Lender Country - ESMA)
    2. RREL84 (Originator Country - ESMA)
    3. RREC6 (Geographic Region NUTS - from AR128)
    4. RREL11 (Geographic Region Obligor NUTS)
    5. AR129 (ECB geographic - sometimes has NUTS codes)
    6. NPEL20/NPEL23 (NPE template country fields)
    7. Pool ID fallback (RMBM/RMBS + 2-letter country)
    """
    # Method 1: RREL81 (clean 2-letter code)
    if 'RREL81' in df.columns:
        vals = df['RREL81'].dropna().astype(str).unique()
        valid = [v for v in vals if len(v) == 2 and v.isalpha()]
        if valid:
            return valid[0].upper()
    
    # Method 2: RREL84 (clean 2-letter code)
    if 'RREL84' in df.columns:
        vals = df['RREL84'].dropna().astype(str).unique()
        valid = [v for v in vals if len(v) == 2 and v.isalpha()]
        if valid:
            return valid[0].upper()
    
    # Method 3: RREC6 (NUTS code - first 2 chars)
    if 'RREC6' in df.columns:
        vals = df['RREC6'].dropna().astype(str).unique()
        for v in vals:
            if len(v) >= 2 and v[:2].isalpha():
                return v[:2].upper()
    
    # Method 4: RREL11 (NUTS code - first 2 chars)
    if 'RREL11' in df.columns:
        vals = df['RREL11'].dropna().astype(str).unique()
        for v in vals:
            if len(v) >= 2 and v[:2].isalpha() and not v.startswith('ND'):
                return v[:2].upper()
    
    # Method 5: AR129 (ECB geographic - check for NUTS pattern)
    if 'AR129' in df.columns:
        vals = df['AR129'].dropna().astype(str).unique()
        for v in vals:
            if len(v) >= 2 and v[:2].isalpha() and not v.startswith('ND'):
                return v[:2].upper()
    
    # Method 6: NPEL20/NPEL23 (NPE template)
    for col in ['NPEL20', 'NPEL23']:
        if col in df.columns:
            vals = df[col].dropna().astype(str).unique()
            valid = [v for v in vals if len(v) == 2 and v.isalpha()]
            if valid:
                return valid[0].upper()
    
    # Method 7: FALLBACK - Extract from pool ID
    if pool_id.startswith('RMBM') or pool_id.startswith('RMBS'):
        country_from_id = pool_id[4:6]
        if country_from_id.isalpha():
            return country_from_id.upper()
    
    return 'UNKNOWN'

print("✓ Country detection function defined")
# Out:
# ✓ Country detection function defined

# %%
# =============================================================================
# CELL 3: Scan All Files and Build Country Index
# =============================================================================
print("Scanning all merged files to build country index...")
print()

file_index = []  # List of {filepath, pool_id, folder, country, size_mb}

for folder in ['matched', 'ecb_only', 'esma_only']:
    folder_path = os.path.join(INPUT_DIR, folder)
    if not os.path.exists(folder_path):
        print(f"Warning: {folder_path} does not exist, skipping...")
        continue
    
    files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
    print(f"Scanning {folder}: {len(files)} files...")
    
    for fname in files:
        filepath = os.path.join(folder_path, fname)
        file_size = os.path.getsize(filepath)
        
        # Read sample to detect country
        df_sample = pd.read_csv(filepath, nrows=100)
        pool_id = fname[:-4]  # Remove .csv extension
        country = detect_country(df_sample, pool_id)
        
        file_index.append({
            'filepath': filepath,
            'filename': fname,
            'pool_id': pool_id,
            'folder': folder,
            'country': country,
            'size_mb': file_size / (1024 * 1024)
        })

print(f"\nTotal files indexed: {len(file_index)}")

# Group by country and build statistics
country_stats = {}
for f in file_index:
    c = f['country']
    if c not in country_stats:
        country_stats[c] = {'count': 0, 'size_mb': 0, 'matched': 0, 'ecb_only': 0, 'esma_only': 0}
    country_stats[c]['count'] += 1
    country_stats[c]['size_mb'] += f['size_mb']
    country_stats[c][f['folder']] += 1

print("\nCountry distribution:")
print("-" * 90)
for country in sorted(country_stats.keys()):
    s = country_stats[country]
    print(f"{country}: {s['count']} files ({s['size_mb']/1024:.1f} GB) | matched={s['matched']}, ecb={s['ecb_only']}, esma={s['esma_only']}")

print()
print(f"Total countries to process: {len(country_stats)}")
# Out:
# Scanning all merged files to build country index...
#
# Scanning matched: 22 files...
# Scanning ecb_only: 36 files...
# Scanning esma_only: 246 files...
# Scanning ecb_only: 36 files...
# Scanning esma_only: 246 files...
#
# Total files indexed: 304
#
# Country distribution:
# ------------------------------------------------------------------------------------------
# BE: 30 files (52.4 GB) | matched=9, ecb=12, esma=9
# DE: 15 files (50.2 GB) | matched=2, ecb=6, esma=7
# ES: 87 files (11.0 GB) | matched=2, ecb=6, esma=79
# FR: 30 files (90.9 GB) | matched=1, ecb=0, esma=29
# IE: 24 files (4.0 GB) | matched=0, ecb=0, esma=24
# IT: 22 files (8.9 GB) | matched=1, ecb=1, esma=20
# NL: 72 files (43.2 GB) | matched=3, ecb=7, esma=62
# PT: 15 files (0.7 GB) | matched=0, ecb=0, esma=15
# UK: 8 files (54.4 GB) | matched=4, ecb=4, esma=0
# UNKNOWN: 1 files (0.1 GB) | matched=0, ecb=0, esma=1
#
# Total countries to process: 10
#
# Total files indexed: 304
#
# Country distribution:
# ------------------------------------------------------------------------------------------
# BE: 30 files (52.4 GB) | matched=9, ecb=12, esma=9
# DE: 15 files (50.2 GB) | matched=2, ecb=6, esma=7
# ES: 87 files (11.0 GB) | matched=2, ecb=6, esma=79
# FR: 30 files (90.9 GB) | matched=1, ecb=0, esma=29
# IE: 24 files (4.0 GB) | matched=0, ecb=0, esma=24
# IT: 22 files (8.9 GB) | matched=1, ecb=1, esma=20
# NL: 72 files (43.2 GB) | matched=3, ecb=7, esma=62
# PT: 15 files (0.7 GB) | matched=0, ecb=0, esma=15
# UK: 8 files (54.4 GB) | matched=4, ecb=4, esma=0
# UNKNOWN: 1 files (0.1 GB) | matched=0, ecb=0, esma=1
#
# Total countries to process: 10

# %%
# =============================================================================
# CELL 4: Define Country Merge Function (VERIFIED - RESUME SAFE)
# =============================================================================
def merge_country_files(country_code, country_files, output_dir, chunk_size=100000):
    """
    Merge all files for a single country into one CSV.
    Uses chunked streaming to handle large files efficiently.
    
    RESUME SAFE:
    - Skips if final output file already exists
    - Cleans up incomplete .tmp files from interrupted runs
    - Returns None if already completed (for skip tracking)
    
    Args:
        country_code: 2-letter country code (e.g., 'IT', 'DE')
        country_files: List of file info dicts for this country
        output_dir: Directory to write output file
        chunk_size: Number of rows per chunk (default 100000)
    
    Returns:
        dict with merge statistics, or None if skipped (already complete)
    """
    output_path = os.path.join(output_dir, f"{country_code}.csv")
    temp_path = output_path + ".tmp"
    
    # =========================================================================
    # RESUME SAFETY: Check if already completed
    # =========================================================================
    if os.path.exists(output_path):
        file_size_gb = os.path.getsize(output_path) / (1024**3)
        print(f"\n  ⏭️  SKIPPING {country_code}: Already exists ({file_size_gb:.2f} GB)")
        return None  # Signal that this was skipped
    
    # Clean up any incomplete temp files from previous interrupted runs
    if os.path.exists(temp_path):
        print(f"\n  🧹 Cleaning up incomplete temp file for {country_code}...")
        os.remove(temp_path)
    
    print(f"\n{'='*70}")
    print(f"PROCESSING: {country_code}")
    print(f"{'='*70}")
    print(f"Files to merge: {len(country_files)}")
    print(f"Output: {output_path}")
    
    # =========================================================================
    # PHASE 1: Scan all files to determine unified column schema
    # =========================================================================
    print("\nPhase 1: Building unified column schema...")
    all_columns = set()
    
    for f in country_files:
        df_header = pd.read_csv(f['filepath'], nrows=0)
        all_columns.update(df_header.columns.tolist())
    
    # Sort for consistent column ordering
    all_columns_sorted = sorted(list(all_columns))
    print(f"  Unified schema: {len(all_columns_sorted)} columns")
    
    # =========================================================================
    # PHASE 2: Stream-merge all files (chunked I/O)
    # =========================================================================
    print("\nPhase 2: Merging files (chunked streaming)...")
    start_time = time.time()
    total_rows = 0
    first_chunk = True
    
    for file_idx, f in enumerate(country_files):
        file_start = time.time()
        file_rows = 0
        
        print(f"  [{file_idx+1}/{len(country_files)}] [{f['folder']}] {f['filename'][:50]}... ({f['size_mb']:.0f} MB)")
        
        # Process file in chunks - NEVER load full file into memory
        for chunk in pd.read_csv(f['filepath'], chunksize=chunk_size, low_memory=False):
            # Add missing columns with NaN (fast operation)
            for col in all_columns_sorted:
                if col not in chunk.columns:
                    chunk[col] = np.nan
            
            # Reorder to unified schema
            chunk = chunk[all_columns_sorted]
            
            # Append to output (write header only on first chunk)
            chunk.to_csv(temp_path, mode='a', index=False, header=first_chunk)
            first_chunk = False
            
            file_rows += len(chunk)
            
            # Free chunk memory
            del chunk
        
        total_rows += file_rows
        file_elapsed = time.time() - file_start
        print(f"       -> {file_rows:,} rows in {file_elapsed:.1f}s")
        
        # Force garbage collection after each file
        gc.collect()
    
    # Rename temp to final
    os.replace(temp_path, output_path)
    
    total_elapsed = time.time() - start_time
    final_size_gb = os.path.getsize(output_path) / (1024**3)
    
    print(f"\n  ✓ COMPLETE: {country_code}")
    print(f"    Total rows: {total_rows:,}")
    print(f"    Columns: {len(all_columns_sorted)}")
    print(f"    File size: {final_size_gb:.2f} GB")
    print(f"    Time: {total_elapsed:.1f}s")
    
    return {
        'country': country_code,
        'files_merged': len(country_files),
        'total_rows': total_rows,
        'columns': len(all_columns_sorted),
        'size_gb': final_size_gb,
        'time_seconds': total_elapsed,
        'output_path': output_path
    }

print("✓ Country merge function defined")
# Out:
# ✓ Country merge function defined

# %%
# =============================================================================
# CELL 5: Process ALL Countries (RESUME SAFE)
# =============================================================================
print("="*90)
print("PROCESSING ALL COUNTRIES (RESUME SAFE)")
print("="*90)
print()

# Get all countries to process
all_countries = sorted(country_stats.keys())
print(f"Countries to process: {all_countries}")
print(f"Total: {len(all_countries)} countries")
print()

# Check for already completed countries
already_done = []
for cc in all_countries:
    check_path = os.path.join(OUTPUT_DIR, f"{cc}.csv")
    if os.path.exists(check_path):
        already_done.append(cc)

if already_done:
    print(f"✓ Already completed (will skip): {already_done}")
    print(f"  Remaining to process: {len(all_countries) - len(already_done)} countries")
print()

# Track results
merge_results = []
skipped_countries = []
failed_countries = []

overall_start = time.time()

for country_idx, country_code in enumerate(all_countries):
    print(f"\n[{country_idx+1}/{len(all_countries)}] Starting {country_code}...")
    
    try:
        # Get files for this country
        country_files = [f for f in file_index if f['country'] == country_code]
        
        # Merge files (returns None if skipped due to existing file)
        result = merge_country_files(
            country_code=country_code,
            country_files=country_files,
            output_dir=OUTPUT_DIR,
            chunk_size=CHUNK_SIZE
        )
        
        if result is None:
            skipped_countries.append(country_code)
        else:
            merge_results.append(result)
        
    except KeyboardInterrupt:
        print(f"\n\n⚠️ INTERRUPTED during {country_code}!")
        print(f"   Cleaning up incomplete temp file...")
        temp_path = os.path.join(OUTPUT_DIR, f"{country_code}.csv.tmp")
        if os.path.exists(temp_path):
            os.remove(temp_path)
            print(f"   ✓ Removed {temp_path}")
        print(f"\n   Resume safe: Re-run this cell to continue from {country_code}")
        raise  # Re-raise to stop execution
        
    except Exception as e:
        print(f"\n  ✗ ERROR processing {country_code}: {str(e)}")
        failed_countries.append({'country': country_code, 'error': str(e)})
        # Clean up temp file on error too
        temp_path = os.path.join(OUTPUT_DIR, f"{country_code}.csv.tmp")
        if os.path.exists(temp_path):
            os.remove(temp_path)
        continue

overall_elapsed = time.time() - overall_start

print("\n" + "="*90)
print("ALL COUNTRIES PROCESSED")
print("="*90)
print(f"\n  New: {len(merge_results)}, Skipped: {len(skipped_countries)}, Failed: {len(failed_countries)}")
# Out:
# ==========================================================================================
# PROCESSING ALL COUNTRIES (RESUME SAFE)
# ==========================================================================================
#
# Countries to process: ['BE', 'DE', 'ES', 'FR', 'IE', 'IT', 'NL', 'PT', 'UK', 'UNKNOWN']
# Total: 10 countries
#
# ✓ Already completed (will skip): ['BE']
#   Remaining to process: 9 countries
#
#
# [1/10] Starting BE...
#
#   ⏭️  SKIPPING BE: Already exists (53.66 GB)
#
# [2/10] Starting DE...
#
#   🧹 Cleaning up incomplete temp file for DE...
#
# ======================================================================
# PROCESSING: DE
# ======================================================================
# Files to merge: 15
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\DE.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/15] [matched] RMBSDE000097100120083.csv... (2402 MB)
#
# ======================================================================
# PROCESSING: DE
# ======================================================================
# Files to merge: 15
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\DE.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/15] [matched] RMBSDE000097100120083.csv... (2402 MB)
#        -> 2,159,244 rows in 99.8s
#   [2/15] [matched] RMBSDE000556100120088.csv... (1145 MB)
#        -> 2,159,244 rows in 99.8s
#   [2/15] [matched] RMBSDE000556100120088.csv... (1145 MB)
#        -> 2,247,162 rows in 101.1s
#   [3/15] [ecb_only] RMBMDE000950100120151.csv... (109 MB)
#        -> 2,247,162 rows in 101.1s
#   [3/15] [ecb_only] RMBMDE000950100120151.csv... (109 MB)
#        -> 106,140 rows in 5.4s
#   [4/15] [ecb_only] RMBSDE000055100120081.csv... (1502 MB)
#        -> 106,140 rows in 5.4s
#   [4/15] [ecb_only] RMBSDE000055100120081.csv... (1502 MB)
#        -> 1,881,272 rows in 80.5s
#   [5/15] [ecb_only] RMBSDE000055100220089.csv... (382 MB)
#        -> 1,881,272 rows in 80.5s
#   [5/15] [ecb_only] RMBSDE000055100220089.csv... (382 MB)
#        -> 509,035 rows in 21.8s
#   [6/15] [ecb_only] RMBSDE000055100320152.csv... (8197 MB)
#        -> 509,035 rows in 21.8s
#   [6/15] [ecb_only] RMBSDE000055100320152.csv... (8197 MB)
#        -> 7,325,954 rows in 325.2s
#   [7/15] [ecb_only] RMBSDE000055100520173.csv... (16905 MB)
#        -> 7,325,954 rows in 325.2s
#   [7/15] [ecb_only] RMBSDE000055100520173.csv... (16905 MB)
#        -> 15,154,221 rows in 655.5s
#   [8/15] [ecb_only] RMBSDE000190100120086.csv... (1377 MB)
#        -> 15,154,221 rows in 655.5s
#   [8/15] [ecb_only] RMBSDE000190100120086.csv... (1377 MB)
#        -> 1,313,593 rows in 53.6s
#   [9/15] [esma_only] 2138001WO21Z3B8Y8K20N202401.csv... (20 MB)
#        -> 1,313,593 rows in 53.6s
#   [9/15] [esma_only] 2138001WO21Z3B8Y8K20N202401.csv... (20 MB)
#        -> 17,760 rows in 0.7s
#   [10/15] [esma_only] 2ZCNRR8UK83OBTEK2170N200801.csv... (1852 MB)
#        -> 17,760 rows in 0.7s
#   [10/15] [esma_only] 2ZCNRR8UK83OBTEK2170N200801.csv... (1852 MB)
#        -> 2,358,532 rows in 98.2s
#   [11/15] [esma_only] 3KXUNHVVQFIJN6RHLO76N202101.csv... (1217 MB)
#        -> 2,358,532 rows in 98.2s
#   [11/15] [esma_only] 3KXUNHVVQFIJN6RHLO76N202101.csv... (1217 MB)
#        -> 1,719,448 rows in 67.4s
#   [12/15] [esma_only] 724500FUE2OO0PBKK238N202501.csv... (5 MB)
#        -> 1,719,448 rows in 67.4s
#   [12/15] [esma_only] 724500FUE2OO0PBKK238N202501.csv... (5 MB)
#        -> 5,775 rows in 0.3s
#   [13/15] [esma_only] 7LTWFZYICNSX8D621K86N201701.csv... (8772 MB)
#        -> 5,775 rows in 0.3s
#   [13/15] [esma_only] 7LTWFZYICNSX8D621K86N201701.csv... (8772 MB)
#        -> 9,892,728 rows in 427.5s
#   [14/15] [esma_only] 7LTWFZYICNSX8D621K86N202507.csv... (877 MB)
#        -> 9,892,728 rows in 427.5s
#   [14/15] [esma_only] 7LTWFZYICNSX8D621K86N202507.csv... (877 MB)
#        -> 963,789 rows in 40.7s
#   [15/15] [esma_only] 851WYGNLUQLFZBSYGB56N202201.csv... (6682 MB)
#        -> 963,789 rows in 40.7s
#   [15/15] [esma_only] 851WYGNLUQLFZBSYGB56N202201.csv... (6682 MB)
#        -> 7,587,853 rows in 315.1s
#
#   ✓ COMPLETE: DE
#     Total rows: 53,242,506
#     Columns: 216
#     File size: 53.73 GB
#     Time: 2293.0s
#
# [3/10] Starting ES...
#
# ======================================================================
# PROCESSING: ES
# ======================================================================
# Files to merge: 87
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\ES.csv
#
# Phase 1: Building unified column schema...
#        -> 7,587,853 rows in 315.1s
#
#   ✓ COMPLETE: DE
#     Total rows: 53,242,506
#     Columns: 216
#     File size: 53.73 GB
#     Time: 2293.0s
#
# [3/10] Starting ES...
#
# ======================================================================
# PROCESSING: ES
# ======================================================================
# Files to merge: 87
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\ES.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/87] [matched] RMBMES000140100120090.csv... (81 MB)
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/87] [matched] RMBMES000140100120090.csv... (81 MB)
#        -> 75,691 rows in 3.5s
#   [2/87] [matched] RMBMES000140100220122.csv... (143 MB)
#        -> 75,691 rows in 3.5s
#   [2/87] [matched] RMBMES000140100220122.csv... (143 MB)
#        -> 131,901 rows in 6.1s
#   [3/87] [ecb_only] RMBMES000138100120037.csv... (149 MB)
#        -> 131,901 rows in 6.1s
#   [3/87] [ecb_only] RMBMES000138100120037.csv... (149 MB)
#        -> 127,860 rows in 5.4s
#   [4/87] [ecb_only] RMBMES000138100220050.csv... (128 MB)
#        -> 127,860 rows in 5.4s
#   [4/87] [ecb_only] RMBMES000138100220050.csv... (128 MB)
#        -> 112,998 rows in 4.9s
#   [5/87] [ecb_only] RMBMES000138100320066.csv... (385 MB)
#        -> 112,998 rows in 4.9s
#   [5/87] [ecb_only] RMBMES000138100320066.csv... (385 MB)
#        -> 374,424 rows in 16.4s
#   [6/87] [ecb_only] RMBSES000045100120098.csv... (9 MB)
#        -> 374,424 rows in 16.4s
#   [6/87] [ecb_only] RMBSES000045100120098.csv... (9 MB)
#        -> 13,182 rows in 0.6s
#   [7/87] [ecb_only] RMBSES000045100220096.csv... (12 MB)
#        -> 13,182 rows in 0.6s
#   [7/87] [ecb_only] RMBSES000045100220096.csv... (12 MB)
#        -> 18,234 rows in 0.6s
#   [8/87] [ecb_only] RMBSES000045100720046.csv... (1 MB)
#        -> 1,766 rows in 0.1s
#   [9/87] [esma_only] 3TK20IVIUJ8J3ZU0QE75N202001.csv... (2534 MB)
#        -> 18,234 rows in 0.6s
#   [8/87] [ecb_only] RMBSES000045100720046.csv... (1 MB)
#        -> 1,766 rows in 0.1s
#   [9/87] [esma_only] 3TK20IVIUJ8J3ZU0QE75N202001.csv... (2534 MB)
#        -> 2,827,339 rows in 128.9s
#   [10/87] [esma_only] 54930056IRBXK0Q1FP96N201601.csv... (10 MB)
#        -> 2,827,339 rows in 128.9s
#   [10/87] [esma_only] 54930056IRBXK0Q1FP96N201601.csv... (10 MB)
#        -> 12,398 rows in 0.5s
#   [11/87] [esma_only] 54930056IRBXK0Q1FP96N201701.csv... (13 MB)
#        -> 12,398 rows in 0.5s
#   [11/87] [esma_only] 54930056IRBXK0Q1FP96N201701.csv... (13 MB)
#        -> 16,602 rows in 0.6s
#   [12/87] [esma_only] 5493006QMFDDMYWIAM13N200401.csv... (4 MB)
#        -> 4,944 rows in 0.2s
#        -> 16,602 rows in 0.6s
#   [12/87] [esma_only] 5493006QMFDDMYWIAM13N200401.csv... (4 MB)
#        -> 4,944 rows in 0.2s
#   [13/87] [esma_only] 5493006QMFDDMYWIAM13N200601.csv... (143 MB)
#   [13/87] [esma_only] 5493006QMFDDMYWIAM13N200601.csv... (143 MB)
#        -> 169,582 rows in 6.9s
#   [14/87] [esma_only] 5493006QMFDDMYWIAM13N200602.csv... (6 MB)
#        -> 169,582 rows in 6.9s
#   [14/87] [esma_only] 5493006QMFDDMYWIAM13N200602.csv... (6 MB)
#        -> 8,550 rows in 0.3s
#   [15/87] [esma_only] 5493006QMFDDMYWIAM13N202002.csv... (961 MB)
#        -> 8,550 rows in 0.3s
#   [15/87] [esma_only] 5493006QMFDDMYWIAM13N202002.csv... (961 MB)
#        -> 1,140,060 rows in 50.1s
#   [16/87] [esma_only] 5493006QMFDDMYWIAM13N202102.csv... (1390 MB)
#        -> 1,140,060 rows in 50.1s
#   [16/87] [esma_only] 5493006QMFDDMYWIAM13N202102.csv... (1390 MB)
#        -> 1,649,705 rows in 72.7s
#   [17/87] [esma_only] 5493007SJLLCTM6J6M37N201001.csv... (27 MB)
#        -> 1,649,705 rows in 72.7s
#   [17/87] [esma_only] 5493007SJLLCTM6J6M37N201001.csv... (27 MB)
#        -> 38,911 rows in 1.4s
#   [18/87] [esma_only] 549300OLBL49CW8CT155N200601.csv... (10 MB)
#        -> 38,911 rows in 1.4s
#   [18/87] [esma_only] 549300OLBL49CW8CT155N200601.csv... (10 MB)
#        -> 14,658 rows in 0.6s
#   [19/87] [esma_only] 549300OLBL49CW8CT155N200602.csv... (19 MB)
#        -> 14,658 rows in 0.6s
#   [19/87] [esma_only] 549300OLBL49CW8CT155N200602.csv... (19 MB)
#        -> 28,425 rows in 1.1s
#   [20/87] [esma_only] 549300OLBL49CW8CT155N200701.csv... (28 MB)
#        -> 28,425 rows in 1.1s
#   [20/87] [esma_only] 549300OLBL49CW8CT155N200701.csv... (28 MB)
#        -> 41,800 rows in 1.5s
#   [21/87] [esma_only] 549300OLBL49CW8CT155N200801.csv... (38 MB)
#        -> 41,800 rows in 1.5s
#   [21/87] [esma_only] 549300OLBL49CW8CT155N200801.csv... (38 MB)
#        -> 56,480 rows in 2.2s
#   [22/87] [esma_only] 549300OLBL49CW8CT155N200901.csv... (45 MB)
#        -> 56,480 rows in 2.2s
#   [22/87] [esma_only] 549300OLBL49CW8CT155N200901.csv... (45 MB)
#        -> 64,430 rows in 2.5s
#   [23/87] [esma_only] 549300U4LIZV0REEQQ46N200601.csv... (21 MB)
#        -> 64,430 rows in 2.5s
#   [23/87] [esma_only] 549300U4LIZV0REEQQ46N200601.csv... (21 MB)
#        -> 26,420 rows in 0.9s
#   [24/87] [esma_only] 549300U4LIZV0REEQQ46N200602.csv... (30 MB)
#        -> 26,420 rows in 0.9s
#   [24/87] [esma_only] 549300U4LIZV0REEQQ46N200602.csv... (30 MB)
#        -> 37,020 rows in 1.4s
#   [25/87] [esma_only] 549300U4LIZV0REEQQ46N200701.csv... (32 MB)
#        -> 37,020 rows in 1.4s
#   [25/87] [esma_only] 549300U4LIZV0REEQQ46N200701.csv... (32 MB)
#        -> 39,240 rows in 1.5s
#   [26/87] [esma_only] 549300U4LIZV0REEQQ46N200702.csv... (34 MB)
#        -> 39,240 rows in 1.5s
#   [26/87] [esma_only] 549300U4LIZV0REEQQ46N200702.csv... (34 MB)
#        -> 42,240 rows in 1.6s
#   [27/87] [esma_only] 549300U4LIZV0REEQQ46N200801.csv... (30 MB)
#        -> 42,240 rows in 1.6s
#   [27/87] [esma_only] 549300U4LIZV0REEQQ46N200801.csv... (30 MB)
#        -> 36,630 rows in 1.4s
#   [28/87] [esma_only] 635400CE9HHFB55PEY43N200602.csv... (13 MB)
#        -> 36,630 rows in 1.4s
#   [28/87] [esma_only] 635400CE9HHFB55PEY43N200602.csv... (13 MB)
#        -> 17,097 rows in 0.7s
#   [29/87] [esma_only] 635400CE9HHFB55PEY43N200701.csv... (12 MB)
#        -> 17,097 rows in 0.7s
#   [29/87] [esma_only] 635400CE9HHFB55PEY43N200701.csv... (12 MB)
#        -> 15,056 rows in 0.6s
#   [30/87] [esma_only] 635400CE9HHFB55PEY43N200801.csv... (22 MB)
#        -> 15,056 rows in 0.6s
#   [30/87] [esma_only] 635400CE9HHFB55PEY43N200801.csv... (22 MB)
#        -> 27,692 rows in 1.1s
#   [31/87] [esma_only] 635400CE9HHFB55PEY43N201601.csv... (53 MB)
#        -> 27,692 rows in 1.1s
#   [31/87] [esma_only] 635400CE9HHFB55PEY43N201601.csv... (53 MB)
#        -> 67,463 rows in 2.6s
#   [32/87] [esma_only] 7CUNS533WID6K7DGFI87N200601.csv... (32 MB)
#        -> 67,463 rows in 2.6s
#   [32/87] [esma_only] 7CUNS533WID6K7DGFI87N200601.csv... (32 MB)
#        -> 44,064 rows in 1.6s
#   [33/87] [esma_only] 7CUNS533WID6K7DGFI87N200701.csv... (51 MB)
#        -> 44,064 rows in 1.6s
#   [33/87] [esma_only] 7CUNS533WID6K7DGFI87N200701.csv... (51 MB)
#        -> 70,064 rows in 2.6s
#   [34/87] [esma_only] 7CUNS533WID6K7DGFI87N200702.csv... (15 MB)
#        -> 70,064 rows in 2.6s
#   [34/87] [esma_only] 7CUNS533WID6K7DGFI87N200702.csv... (15 MB)
#        -> 21,154 rows in 0.7s
#   [35/87] [esma_only] 7CUNS533WID6K7DGFI87N200703.csv... (39 MB)
#        -> 21,154 rows in 0.7s
#   [35/87] [esma_only] 7CUNS533WID6K7DGFI87N200703.csv... (39 MB)
#        -> 53,647 rows in 2.0s
#   [36/87] [esma_only] 7CUNS533WID6K7DGFI87N200801.csv... (59 MB)
#        -> 53,647 rows in 2.0s
#   [36/87] [esma_only] 7CUNS533WID6K7DGFI87N200801.csv... (59 MB)
#        -> 80,741 rows in 3.1s
#   [37/87] [esma_only] 9598000HT3WLVN4DB470N201401.csv... (2 MB)
#        -> 2,509 rows in 0.1s
#   [38/87] [esma_only] 95980020140005012943N201301.csv... (6 MB)
#        -> 80,741 rows in 3.1s
#   [37/87] [esma_only] 9598000HT3WLVN4DB470N201401.csv... (2 MB)
#        -> 2,509 rows in 0.1s
#   [38/87] [esma_only] 95980020140005012943N201301.csv... (6 MB)
#        -> 7,133 rows in 0.3s
#   [39/87] [esma_only] 95980020140005012943N201801.csv... (15 MB)
#        -> 7,133 rows in 0.3s
#   [39/87] [esma_only] 95980020140005012943N201801.csv... (15 MB)
#        -> 19,358 rows in 0.8s
#   [40/87] [esma_only] 95980020140005209368N202001.csv... (86 MB)
#        -> 19,358 rows in 0.8s
#   [40/87] [esma_only] 95980020140005209368N202001.csv... (86 MB)
#        -> 88,860 rows in 3.9s
#   [41/87] [esma_only] 95980020140005209368N202101.csv... (82 MB)
#        -> 88,860 rows in 3.9s
#   [41/87] [esma_only] 95980020140005209368N202101.csv... (82 MB)
#        -> 84,044 rows in 3.9s
#   [42/87] [esma_only] 95980020140005209368N202102.csv... (78 MB)
#        -> 84,044 rows in 3.9s
#   [42/87] [esma_only] 95980020140005209368N202102.csv... (78 MB)
#        -> 79,390 rows in 3.5s
#   [43/87] [esma_only] 95980020140005209368N202201.csv... (87 MB)
#        -> 79,390 rows in 3.5s
#   [43/87] [esma_only] 95980020140005209368N202201.csv... (87 MB)
#        -> 89,665 rows in 3.8s
#   [44/87] [esma_only] 95980020140005209368N202301.csv... (50 MB)
#        -> 89,665 rows in 3.8s
#   [44/87] [esma_only] 95980020140005209368N202301.csv... (50 MB)
#        -> 51,212 rows in 2.1s
#   [45/87] [esma_only] 95980020140005209659N201001.csv... (42 MB)
#        -> 51,212 rows in 2.1s
#   [45/87] [esma_only] 95980020140005209659N201001.csv... (42 MB)
#        -> 67,517 rows in 2.5s
#   [46/87] [esma_only] 95980020140005209756N201101.csv... (11 MB)
#        -> 67,517 rows in 2.5s
#   [46/87] [esma_only] 95980020140005209756N201101.csv... (11 MB)
#        -> 17,593 rows in 0.6s
#   [47/87] [esma_only] 95980020140005209853N201101.csv... (13 MB)
#        -> 17,593 rows in 0.6s
#   [47/87] [esma_only] 95980020140005209853N201101.csv... (13 MB)
#        -> 20,586 rows in 0.8s
#   [48/87] [esma_only] 95980020140005212763N200801.csv... (6 MB)
#        -> 20,586 rows in 0.8s
#   [48/87] [esma_only] 95980020140005212763N200801.csv... (6 MB)
#        -> 10,027 rows in 0.4s
#   [49/87] [esma_only] 95980020140005212860N200701.csv... (8 MB)
#        -> 10,027 rows in 0.4s
#   [49/87] [esma_only] 95980020140005212860N200701.csv... (8 MB)
#        -> 12,503 rows in 0.5s
#   [50/87] [esma_only] 95980020140005212957N200601.csv... (7 MB)
#        -> 12,503 rows in 0.5s
#   [50/87] [esma_only] 95980020140005212957N200601.csv... (7 MB)
#        -> 11,820 rows in 0.5s
#   [51/87] [esma_only] 95980020140005213054N200601.csv... (8 MB)
#        -> 11,820 rows in 0.5s
#   [51/87] [esma_only] 95980020140005213054N200601.csv... (8 MB)
#        -> 12,695 rows in 0.4s
#   [52/87] [esma_only] 95980020140005216158N200701.csv... (10 MB)
#        -> 12,695 rows in 0.4s
#   [52/87] [esma_only] 95980020140005216158N200701.csv... (10 MB)
#        -> 16,323 rows in 0.6s
#   [53/87] [esma_only] 95980020140005216158N200802.csv... (4 MB)
#        -> 16,323 rows in 0.6s
#   [53/87] [esma_only] 95980020140005216158N200802.csv... (4 MB)
#        -> 6,168 rows in 0.2s
#   [54/87] [esma_only] 95980020140005310927N202201.csv... (19 MB)
#        -> 6,168 rows in 0.2s
#   [54/87] [esma_only] 95980020140005310927N202201.csv... (19 MB)
#        -> 26,587 rows in 0.9s
#   [55/87] [esma_only] 95980020140005501435N200701.csv... (24 MB)
#        -> 26,587 rows in 0.9s
#   [55/87] [esma_only] 95980020140005501435N200701.csv... (24 MB)
#        -> 29,750 rows in 1.1s
#   [56/87] [esma_only] 95980020140005501629N200601.csv... (8 MB)
#        -> 29,750 rows in 1.1s
#   [56/87] [esma_only] 95980020140005501629N200601.csv... (8 MB)
#        -> 9,573 rows in 0.4s
#   [57/87] [esma_only] 959800521QYXV2UA6L30N202001.csv... (70 MB)
#        -> 9,573 rows in 0.4s
#   [57/87] [esma_only] 959800521QYXV2UA6L30N202001.csv... (70 MB)
#        -> 88,994 rows in 3.6s
#   [58/87] [esma_only] 95980094CL01DWRL6C36N201301.csv... (17 MB)
#        -> 88,994 rows in 3.6s
#   [58/87] [esma_only] 95980094CL01DWRL6C36N201301.csv... (17 MB)
#        -> 20,416 rows in 0.8s
#   [59/87] [esma_only] 959800AJTB9KP9HKB323N202401.csv... (65 MB)
#        -> 20,416 rows in 0.8s
#   [59/87] [esma_only] 959800AJTB9KP9HKB323N202401.csv... (65 MB)
#        -> 82,288 rows in 3.5s
#   [60/87] [esma_only] 959800CVG0VNETWAF746N202501.csv... (46 MB)
#        -> 82,288 rows in 3.5s
#   [60/87] [esma_only] 959800CVG0VNETWAF746N202501.csv... (46 MB)
#        -> 58,441 rows in 2.5s
#   [61/87] [esma_only] 959800LQ598A5RQASA61N200612.csv... (6 MB)
#        -> 58,441 rows in 2.5s
#   [61/87] [esma_only] 959800LQ598A5RQASA61N200612.csv... (6 MB)
#        -> 8,861 rows in 0.4s
#   [62/87] [esma_only] 959800LQ598A5RQASA61N200713.csv... (7 MB)
#        -> 8,861 rows in 0.4s
#   [62/87] [esma_only] 959800LQ598A5RQASA61N200713.csv... (7 MB)
#        -> 9,597 rows in 0.4s
#   [63/87] [esma_only] 959800LQ598A5RQASA61N200814.csv... (6 MB)
#        -> 9,597 rows in 0.4s
#   [63/87] [esma_only] 959800LQ598A5RQASA61N200814.csv... (6 MB)
#        -> 9,213 rows in 0.3s
#   [64/87] [esma_only] 959800R8CQLEK6JWF651N201601.csv... (426 MB)
#        -> 9,213 rows in 0.3s
#   [64/87] [esma_only] 959800R8CQLEK6JWF651N201601.csv... (426 MB)
#        -> 572,142 rows in 24.3s
#   [65/87] [esma_only] 959800R8CQLEK6JWF651N201701.csv... (112 MB)
#        -> 572,142 rows in 24.3s
#   [65/87] [esma_only] 959800R8CQLEK6JWF651N201701.csv... (112 MB)
#        -> 152,342 rows in 6.6s
#   [66/87] [esma_only] 959800R8CQLEK6JWF651N201704.csv... (217 MB)
#        -> 152,342 rows in 6.6s
#   [66/87] [esma_only] 959800R8CQLEK6JWF651N201704.csv... (217 MB)
#        -> 294,948 rows in 12.3s
#   [67/87] [esma_only] 959800SK3N802RGT5340N201301.csv... (3 MB)
#        -> 4,316 rows in 0.2s
#   [68/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200506.csv... (13 MB)
#        -> 294,948 rows in 12.3s
#   [67/87] [esma_only] 959800SK3N802RGT5340N201301.csv... (3 MB)
#        -> 4,316 rows in 0.2s
#   [68/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200506.csv... (13 MB)
#        -> 16,193 rows in 0.6s
#   [69/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200602.csv... (22 MB)
#        -> 16,193 rows in 0.6s
#   [69/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200602.csv... (22 MB)
#        -> 26,954 rows in 1.0s
#   [70/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200701.csv... (67 MB)
#        -> 26,954 rows in 1.0s
#   [70/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200701.csv... (67 MB)
#        -> 83,792 rows in 3.4s
#   [71/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200702.csv... (22 MB)
#        -> 83,792 rows in 3.4s
#   [71/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200702.csv... (22 MB)
#        -> 27,462 rows in 1.1s
#   [72/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200703.csv... (115 MB)
#        -> 27,462 rows in 1.1s
#   [72/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N200703.csv... (115 MB)
#        -> 144,355 rows in 5.8s
#   [73/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N201403.csv... (35 MB)
#        -> 144,355 rows in 5.8s
#   [73/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N201403.csv... (35 MB)
#        -> 44,444 rows in 1.6s
#   [74/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N201902.csv... (163 MB)
#        -> 44,444 rows in 1.6s
#   [74/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N201902.csv... (163 MB)
#        -> 209,648 rows in 8.9s
#   [75/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202102.csv... (297 MB)
#        -> 209,648 rows in 8.9s
#   [75/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202102.csv... (297 MB)
#        -> 374,997 rows in 15.1s
#   [76/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202201.csv... (1794 MB)
#        -> 374,997 rows in 15.1s
#   [76/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202201.csv... (1794 MB)
#        -> 2,265,834 rows in 94.1s
#   [77/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202203.csv... (111 MB)
#        -> 2,265,834 rows in 94.1s
#   [77/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202203.csv... (111 MB)
#        -> 140,531 rows in 6.0s
#   [78/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202404.csv... (305 MB)
#        -> 140,531 rows in 6.0s
#   [78/87] [esma_only] K8MS7FD7N5Z2WQ51AZ71N202404.csv... (305 MB)
#        -> 385,606 rows in 15.9s
#   [79/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200504.csv... (13 MB)
#        -> 385,606 rows in 15.9s
#   [79/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200504.csv... (13 MB)
#        -> 19,365 rows in 0.7s
#   [80/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200505.csv... (21 MB)
#        -> 19,365 rows in 0.7s
#   [80/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200505.csv... (21 MB)
#        -> 30,248 rows in 1.1s
#   [81/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200607.csv... (17 MB)
#        -> 30,248 rows in 1.1s
#   [81/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200607.csv... (17 MB)
#        -> 24,197 rows in 0.9s
#   [82/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200608.csv... (9 MB)
#        -> 24,197 rows in 0.9s
#   [82/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200608.csv... (9 MB)
#        -> 12,291 rows in 0.5s
#   [83/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200709.csv... (17 MB)
#        -> 12,291 rows in 0.5s
#   [83/87] [esma_only] SI5RG2M0WQQLZCXKRM20N200709.csv... (17 MB)
#        -> 23,909 rows in 0.9s
#   [84/87] [esma_only] SI5RG2M0WQQLZCXKRM20N201710.csv... (50 MB)
#        -> 23,909 rows in 0.9s
#   [84/87] [esma_only] SI5RG2M0WQQLZCXKRM20N201710.csv... (50 MB)
#        -> 72,672 rows in 2.8s
#   [85/87] [esma_only] SI5RG2M0WQQLZCXKRM20N202501.csv... (97 MB)
#        -> 72,672 rows in 2.8s
#   [85/87] [esma_only] SI5RG2M0WQQLZCXKRM20N202501.csv... (97 MB)
#        -> 140,471 rows in 5.9s
#   [86/87] [esma_only] VWMYAEQSTOPNV0SUGU82N200501.csv... (5 MB)
#        -> 140,471 rows in 5.9s
#   [86/87] [esma_only] VWMYAEQSTOPNV0SUGU82N200501.csv... (5 MB)
#        -> 6,149 rows in 0.3s
#   [87/87] [esma_only] VWMYAEQSTOPNV0SUGU82N200601.csv... (17 MB)
#        -> 6,149 rows in 0.3s
#   [87/87] [esma_only] VWMYAEQSTOPNV0SUGU82N200601.csv... (17 MB)
#        -> 22,857 rows in 0.9s
#
#   ✓ COMPLETE: ES
#     Total rows: 13,545,314
#     Columns: 216
#     File size: 12.19 GB
#     Time: 580.6s
#
# [4/10] Starting FR...
#
# ======================================================================
# PROCESSING: FR
# ======================================================================
# Files to merge: 30
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\FR.csv
#
# Phase 1: Building unified column schema...
#        -> 22,857 rows in 0.9s
#
#   ✓ COMPLETE: ES
#     Total rows: 13,545,314
#     Columns: 216
#     File size: 12.19 GB
#     Time: 580.6s
#
# [4/10] Starting FR...
#
# ======================================================================
# PROCESSING: FR
# ======================================================================
# Files to merge: 30
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\FR.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 215 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/30] [matched] RMBMFR000083100220149.csv... (85666 MB)
#   Unified schema: 215 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/30] [matched] RMBMFR000083100220149.csv... (85666 MB)
#        -> 82,479,766 rows in 4004.9s
#   [2/30] [esma_only] 54930002GQ40DD57AK55N201801.csv... (34 MB)
#        -> 82,479,766 rows in 4004.9s
#   [2/30] [esma_only] 54930002GQ40DD57AK55N201801.csv... (34 MB)
#        -> 48,180 rows in 1.9s
#   [3/30] [esma_only] 5493001Y7OCB84GOJ429N202001.csv... (107 MB)
#        -> 48,180 rows in 1.9s
#   [3/30] [esma_only] 5493001Y7OCB84GOJ429N202001.csv... (107 MB)
#        -> 127,409 rows in 6.3s
#   [4/30] [esma_only] 54930032M1SQPJNRZ420N201901.csv... (99 MB)
#        -> 127,409 rows in 6.3s
#   [4/30] [esma_only] 54930032M1SQPJNRZ420N201901.csv... (99 MB)
#        -> 117,013 rows in 5.7s
#   [5/30] [esma_only] 5493005TM46YMTICAU84N202201.csv... (128 MB)
#        -> 117,013 rows in 5.7s
#   [5/30] [esma_only] 5493005TM46YMTICAU84N202201.csv... (128 MB)
#        -> 173,628 rows in 7.8s
#   [6/30] [esma_only] 549300CV91UZJXB8RL09N202301.csv... (80 MB)
#        -> 173,628 rows in 7.8s
#   [6/30] [esma_only] 549300CV91UZJXB8RL09N202301.csv... (80 MB)
#        -> 95,861 rows in 4.5s
#   [7/30] [esma_only] 549300GP8VGBVVL86O86N201801.csv... (49 MB)
#        -> 95,861 rows in 4.5s
#   [7/30] [esma_only] 549300GP8VGBVVL86O86N201801.csv... (49 MB)
#        -> 58,768 rows in 2.6s
#   [8/30] [esma_only] 549300HXUI1QLHV9NT89N201701.csv... (71 MB)
#        -> 58,768 rows in 2.6s
#   [8/30] [esma_only] 549300HXUI1QLHV9NT89N201701.csv... (71 MB)
#        -> 101,180 rows in 4.7s
#   [9/30] [esma_only] 549300MIF85K8BXC6M91N202101.csv... (227 MB)
#        -> 101,180 rows in 4.7s
#   [9/30] [esma_only] 549300MIF85K8BXC6M91N202101.csv... (227 MB)
#        -> 307,972 rows in 14.3s
#   [10/30] [esma_only] 549300RUEYYMW163W968N201702.csv... (31 MB)
#        -> 307,972 rows in 14.3s
#   [10/30] [esma_only] 549300RUEYYMW163W968N201702.csv... (31 MB)
#        -> 44,880 rows in 1.9s
#   [11/30] [esma_only] 549300V6B3GYHJKZU741N201701.csv... (855 MB)
#        -> 44,880 rows in 1.9s
#   [11/30] [esma_only] 549300V6B3GYHJKZU741N201701.csv... (855 MB)
#        -> 1,029,837 rows in 48.9s
#   [12/30] [esma_only] 549300WBHY25B75DWR71N201401.csv... (5 MB)
#        -> 1,029,837 rows in 48.9s
#   [12/30] [esma_only] 549300WBHY25B75DWR71N201401.csv... (5 MB)
#        -> 7,332 rows in 0.3s
#   [13/30] [esma_only] 549300XY136B5UBOKZ47N201401.csv... (475 MB)
#        -> 7,332 rows in 0.3s
#   [13/30] [esma_only] 549300XY136B5UBOKZ47N201401.csv... (475 MB)
#        -> 636,370 rows in 28.9s
#   [14/30] [esma_only] 9695000NVUKTJ495CJ05N202401.csv... (554 MB)
#        -> 636,370 rows in 28.9s
#   [14/30] [esma_only] 9695000NVUKTJ495CJ05N202401.csv... (554 MB)
#        -> 683,652 rows in 31.7s
#   [15/30] [esma_only] 9695003SJ7Z9C9HIGV14N202201.csv... (148 MB)
#        -> 683,652 rows in 31.7s
#   [15/30] [esma_only] 9695003SJ7Z9C9HIGV14N202201.csv... (148 MB)
#        -> 207,657 rows in 8.6s
#   [16/30] [esma_only] 969500651HMG0IO6S894N201901.csv... (125 MB)
#        -> 207,657 rows in 8.6s
#   [16/30] [esma_only] 969500651HMG0IO6S894N201901.csv... (125 MB)
#        -> 177,968 rows in 7.0s
#   [17/30] [esma_only] 9695008RHUDZ68X7SV34N202501.csv... (19 MB)
#        -> 177,968 rows in 7.0s
#   [17/30] [esma_only] 9695008RHUDZ68X7SV34N202501.csv... (19 MB)
#        -> 26,684 rows in 1.0s
#   [18/30] [esma_only] 969500BEY2ZTHR3JG165N202401.csv... (60 MB)
#        -> 26,684 rows in 1.0s
#   [18/30] [esma_only] 969500BEY2ZTHR3JG165N202401.csv... (60 MB)
#        -> 78,397 rows in 3.1s
#   [19/30] [esma_only] 969500EF6ED9WU4JFN81N202201.csv... (148 MB)
#        -> 78,397 rows in 3.1s
#   [19/30] [esma_only] 969500EF6ED9WU4JFN81N202201.csv... (148 MB)
#        -> 192,763 rows in 8.6s
#   [20/30] [esma_only] 969500FEKK527RVCPM68N202401.csv... (18 MB)
#        -> 192,763 rows in 8.6s
#   [20/30] [esma_only] 969500FEKK527RVCPM68N202401.csv... (18 MB)
#        -> 22,298 rows in 0.9s
#   [21/30] [esma_only] 969500JLLGA7AQZQ1L92N202001.csv... (187 MB)
#        -> 22,298 rows in 0.9s
#   [21/30] [esma_only] 969500JLLGA7AQZQ1L92N202001.csv... (187 MB)
#        -> 263,736 rows in 11.6s
#   [22/30] [esma_only] 969500KPK1WZO8QA4W81N202101.csv... (180 MB)
#        -> 263,736 rows in 11.6s
#   [22/30] [esma_only] 969500KPK1WZO8QA4W81N202101.csv... (180 MB)
#        -> 260,168 rows in 10.8s
#   [23/30] [esma_only] 969500LXTMN8327PHD94N202501.csv... (38 MB)
#        -> 260,168 rows in 10.8s
#   [23/30] [esma_only] 969500LXTMN8327PHD94N202501.csv... (38 MB)
#        -> 49,565 rows in 2.2s
#   [24/30] [esma_only] 969500MFD98SLZ425M62N202001.csv... (155 MB)
#        -> 49,565 rows in 2.2s
#   [24/30] [esma_only] 969500MFD98SLZ425M62N202001.csv... (155 MB)
#        -> 202,561 rows in 10.0s
#   [25/30] [esma_only] 969500QV655PJVGV0544N202001.csv... (144 MB)
#        -> 202,561 rows in 10.0s
#   [25/30] [esma_only] 969500QV655PJVGV0544N202001.csv... (144 MB)
#        -> 204,372 rows in 8.8s
#   [26/30] [esma_only] 969500TJWRCC8CMQWT96N202401.csv... (46 MB)
#        -> 204,372 rows in 8.8s
#   [26/30] [esma_only] 969500TJWRCC8CMQWT96N202401.csv... (46 MB)
#        -> 61,674 rows in 2.5s
#   [27/30] [esma_only] 969500XG6BPNADMZBB17N201901.csv... (2041 MB)
#        -> 61,674 rows in 2.5s
#   [27/30] [esma_only] 969500XG6BPNADMZBB17N201901.csv... (2041 MB)
#        -> 2,708,929 rows in 125.2s
#   [28/30] [esma_only] 984500415841D00D2F22N202501.csv... (9 MB)
#        -> 2,708,929 rows in 125.2s
#   [28/30] [esma_only] 984500415841D00D2F22N202501.csv... (9 MB)
#        -> 11,611 rows in 0.5s
#   [29/30] [esma_only] 984500B8E9RW7C014018N202501.csv... (8 MB)
#        -> 11,611 rows in 0.5s
#   [29/30] [esma_only] 984500B8E9RW7C014018N202501.csv... (8 MB)
#        -> 9,719 rows in 0.4s
#   [30/30] [esma_only] O2RNE8IBXP4R0TD8PU41N202201.csv... (1328 MB)
#        -> 9,719 rows in 0.4s
#   [30/30] [esma_only] O2RNE8IBXP4R0TD8PU41N202201.csv... (1328 MB)
#        -> 1,644,440 rows in 76.8s
#
#   ✓ COMPLETE: FR
#     Total rows: 92,034,390
#     Columns: 215
#     File size: 91.68 GB
#     Time: 4443.1s
#
# [5/10] Starting IE...
#
# ======================================================================
# PROCESSING: IE
# ======================================================================
# Files to merge: 24
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\IE.csv
#
# Phase 1: Building unified column schema...
#        -> 1,644,440 rows in 76.8s
#
#   ✓ COMPLETE: FR
#     Total rows: 92,034,390
#     Columns: 215
#     File size: 91.68 GB
#     Time: 4443.1s
#
# [5/10] Starting IE...
#
# ======================================================================
# PROCESSING: IE
# ======================================================================
# Files to merge: 24
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\IE.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 196 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/24] [esma_only] 549300WL1M55G8FIDZ68N202101.csv... (1226 MB)
#   Unified schema: 196 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/24] [esma_only] 549300WL1M55G8FIDZ68N202101.csv... (1226 MB)
#        -> 1,314,168 rows in 57.5s
#   [2/24] [esma_only] 549300WL1M55G8FIDZ68N202102.csv... (430 MB)
#        -> 1,314,168 rows in 57.5s
#   [2/24] [esma_only] 549300WL1M55G8FIDZ68N202102.csv... (430 MB)
#        -> 463,933 rows in 19.5s
#   [3/24] [esma_only] 549300WL1M55G8FIDZ68N202201.csv... (673 MB)
#        -> 463,933 rows in 19.5s
#   [3/24] [esma_only] 549300WL1M55G8FIDZ68N202201.csv... (673 MB)
#        -> 716,226 rows in 31.1s
#   [4/24] [esma_only] 549300WL1M55G8FIDZ68N202401.csv... (89 MB)
#        -> 716,226 rows in 31.1s
#   [4/24] [esma_only] 549300WL1M55G8FIDZ68N202401.csv... (89 MB)
#        -> 93,615 rows in 4.0s
#   [5/24] [esma_only] 549300YIM8RX3KHGIU35N201901.csv... (4 MB)
#        -> 93,615 rows in 4.0s
#   [5/24] [esma_only] 549300YIM8RX3KHGIU35N201901.csv... (4 MB)
#        -> 5,456 rows in 0.2s
#   [6/24] [esma_only] 549300YIM8RX3KHGIU35N202001.csv... (9 MB)
#        -> 5,456 rows in 0.2s
#   [6/24] [esma_only] 549300YIM8RX3KHGIU35N202001.csv... (9 MB)
#        -> 11,304 rows in 0.4s
#   [7/24] [esma_only] 549300YIM8RX3KHGIU35N202101.csv... (11 MB)
#        -> 11,304 rows in 0.4s
#   [7/24] [esma_only] 549300YIM8RX3KHGIU35N202101.csv... (11 MB)
#        -> 14,064 rows in 0.5s
#   [8/24] [esma_only] 549300YIM8RX3KHGIU35N202201.csv... (15 MB)
#        -> 14,064 rows in 0.5s
#   [8/24] [esma_only] 549300YIM8RX3KHGIU35N202201.csv... (15 MB)
#        -> 18,774 rows in 0.6s
#   [9/24] [esma_only] 6354001ECZ5C5ROCKB97N201901.csv... (10 MB)
#        -> 18,774 rows in 0.6s
#   [9/24] [esma_only] 6354001ECZ5C5ROCKB97N201901.csv... (10 MB)
#        -> 13,816 rows in 0.4s
#   [10/24] [esma_only] 6354008Z6PDP7AXBAD38N201901.csv... (2 MB)
#        -> 3,457 rows in 0.1s
#   [11/24] [esma_only] 6354008Z6PDP7AXBAD38N202101.csv... (10 MB)
#        -> 13,816 rows in 0.4s
#   [10/24] [esma_only] 6354008Z6PDP7AXBAD38N201901.csv... (2 MB)
#        -> 3,457 rows in 0.1s
#   [11/24] [esma_only] 6354008Z6PDP7AXBAD38N202101.csv... (10 MB)
#        -> 14,999 rows in 0.6s
#   [12/24] [esma_only] 6354008Z6PDP7AXBAD38N202102.csv... (15 MB)
#        -> 14,999 rows in 0.6s
#   [12/24] [esma_only] 6354008Z6PDP7AXBAD38N202102.csv... (15 MB)
#        -> 21,705 rows in 0.7s
#   [13/24] [esma_only] 6354008Z6PDP7AXBAD38N202301.csv... (20 MB)
#        -> 21,705 rows in 0.7s
#   [13/24] [esma_only] 6354008Z6PDP7AXBAD38N202301.csv... (20 MB)
#        -> 27,470 rows in 1.0s
#   [14/24] [esma_only] 6354008Z6PDP7AXBAD38N202302.csv... (11 MB)
#        -> 27,470 rows in 1.0s
#   [14/24] [esma_only] 6354008Z6PDP7AXBAD38N202302.csv... (11 MB)
#        -> 15,513 rows in 0.5s
#   [15/24] [esma_only] 6354008Z6PDP7AXBAD38N202401.csv... (11 MB)
#        -> 15,513 rows in 0.5s
#   [15/24] [esma_only] 6354008Z6PDP7AXBAD38N202401.csv... (11 MB)
#        -> 14,091 rows in 0.6s
#   [16/24] [esma_only] 6354008Z6PDP7AXBAD38N202402.csv... (4 MB)
#        -> 14,091 rows in 0.6s
#   [16/24] [esma_only] 6354008Z6PDP7AXBAD38N202402.csv... (4 MB)
#        -> 6,124 rows in 0.2s
#   [17/24] [esma_only] 635400AJEHTFGD5HYS44N202101.csv... (57 MB)
#        -> 6,124 rows in 0.2s
#   [17/24] [esma_only] 635400AJEHTFGD5HYS44N202101.csv... (57 MB)
#        -> 78,934 rows in 2.8s
#   [18/24] [esma_only] 635400DJAT97IZDCJN35N202002.csv... (934 MB)
#        -> 78,934 rows in 2.8s
#   [18/24] [esma_only] 635400DJAT97IZDCJN35N202002.csv... (934 MB)
#        -> 1,290,963 rows in 54.2s
#   [19/24] [esma_only] 635400DYIVV4EPKDBN26N202201.csv... (53 MB)
#        -> 1,290,963 rows in 54.2s
#   [19/24] [esma_only] 635400DYIVV4EPKDBN26N202201.csv... (53 MB)
#        -> 73,098 rows in 2.3s
#   [20/24] [esma_only] 635400IU9RIO17FMKE17N202401.csv... (8 MB)
#        -> 73,098 rows in 2.3s
#   [20/24] [esma_only] 635400IU9RIO17FMKE17N202401.csv... (8 MB)
#        -> 9,625 rows in 0.3s
#   [21/24] [esma_only] 635400KOA4XWWG9CDC43N202301.csv... (289 MB)
#        -> 9,625 rows in 0.3s
#   [21/24] [esma_only] 635400KOA4XWWG9CDC43N202301.csv... (289 MB)
#        -> 396,231 rows in 15.5s
#   [22/24] [esma_only] 635400VOFDHJRN8DSL34N202201.csv... (18 MB)
#        -> 396,231 rows in 15.5s
#   [22/24] [esma_only] 635400VOFDHJRN8DSL34N202201.csv... (18 MB)
#        -> 22,438 rows in 0.9s
#   [23/24] [esma_only] 635400X6AORFVBGWOY71N202401.csv... (165 MB)
#        -> 22,438 rows in 0.9s
#   [23/24] [esma_only] 635400X6AORFVBGWOY71N202401.csv... (165 MB)
#        -> 215,050 rows in 9.0s
#   [24/24] [esma_only] 635400ZYEGNCE4TCV776N202301.csv... (7 MB)
#        -> 215,050 rows in 9.0s
#   [24/24] [esma_only] 635400ZYEGNCE4TCV776N202301.csv... (7 MB)
#        -> 8,936 rows in 0.4s
#
#   ✓ COMPLETE: IE
#     Total rows: 4,849,990
#     Columns: 196
#     File size: 4.31 GB
#     Time: 204.0s
#
# [6/10] Starting IT...
#
# ======================================================================
# PROCESSING: IT
# ======================================================================
# Files to merge: 22
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\IT.csv
#
# Phase 1: Building unified column schema...
#        -> 8,936 rows in 0.4s
#
#   ✓ COMPLETE: IE
#     Total rows: 4,849,990
#     Columns: 196
#     File size: 4.31 GB
#     Time: 204.0s
#
# [6/10] Starting IT...
#
# ======================================================================
# PROCESSING: IT
# ======================================================================
# Files to merge: 22
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\IT.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/22] [matched] RMBMIT000103100520171.csv... (5851 MB)
#   Unified schema: 216 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/22] [matched] RMBMIT000103100520171.csv... (5851 MB)
#        -> 6,918,499 rows in 315.4s
#   [2/22] [ecb_only] RMBMIT000103100220095.csv... (141 MB)
#        -> 6,918,499 rows in 315.4s
#   [2/22] [ecb_only] RMBMIT000103100220095.csv... (141 MB)
#        -> 323,878 rows in 12.6s
#   [3/22] [esma_only] 2W8N8UU78PMDQKZENC08N201901.csv... (563 MB)
#        -> 323,878 rows in 12.6s
#   [3/22] [esma_only] 2W8N8UU78PMDQKZENC08N201901.csv... (563 MB)
#        -> 798,036 rows in 31.7s
#   [4/22] [esma_only] 3TK20IVIUJ8J3ZU0QE75N202302.csv... (685 MB)
#        -> 798,036 rows in 31.7s
#   [4/22] [esma_only] 3TK20IVIUJ8J3ZU0QE75N202302.csv... (685 MB)
#        -> 778,910 rows in 35.9s
#   [5/22] [esma_only] 549300B0FLNFTFYQDJ30N201701.csv... (35 MB)
#        -> 778,910 rows in 35.9s
#   [5/22] [esma_only] 549300B0FLNFTFYQDJ30N201701.csv... (35 MB)
#        -> 31,518 rows in 1.4s
#   [6/22] [esma_only] 549300TRUWO2CD2G5692N200701.csv... (22 MB)
#        -> 31,518 rows in 1.4s
#   [6/22] [esma_only] 549300TRUWO2CD2G5692N200701.csv... (22 MB)
#        -> 29,952 rows in 1.1s
#   [7/22] [esma_only] 549300UE2ZF21B02QG64N201701.csv... (25 MB)
#        -> 29,952 rows in 1.1s
#   [7/22] [esma_only] 549300UE2ZF21B02QG64N201701.csv... (25 MB)
#        -> 33,868 rows in 1.4s
#   [8/22] [esma_only] 549300UE2ZF21B02QG64N201801.csv... (32 MB)
#        -> 33,868 rows in 1.4s
#   [8/22] [esma_only] 549300UE2ZF21B02QG64N201801.csv... (32 MB)
#        -> 44,814 rows in 1.8s
#   [9/22] [esma_only] 549300UE2ZF21B02QG64N201901.csv... (39 MB)
#        -> 44,814 rows in 1.8s
#   [9/22] [esma_only] 549300UE2ZF21B02QG64N201901.csv... (39 MB)
#        -> 53,087 rows in 2.0s
#   [10/22] [esma_only] 81560027D07F9BDB8436N202101.csv... (176 MB)
#        -> 53,087 rows in 2.0s
#   [10/22] [esma_only] 81560027D07F9BDB8436N202101.csv... (176 MB)
#        -> 194,959 rows in 8.5s
#   [11/22] [esma_only] 81560027D07F9BDB8436N202401.csv... (35 MB)
#        -> 194,959 rows in 8.5s
#   [11/22] [esma_only] 81560027D07F9BDB8436N202401.csv... (35 MB)
#        -> 38,134 rows in 1.4s
#   [12/22] [esma_only] 8156003A4FB445454553N201801.csv... (10 MB)
#        -> 38,134 rows in 1.4s
#   [12/22] [esma_only] 8156003A4FB445454553N201801.csv... (10 MB)
#        -> 12,741 rows in 0.5s
#   [13/22] [esma_only] 8156004B244AA70DE787N201400.csv... (399 MB)
#        -> 12,741 rows in 0.5s
#   [13/22] [esma_only] 8156004B244AA70DE787N201400.csv... (399 MB)
#        -> 490,276 rows in 22.1s
#   [14/22] [esma_only] 8156005A8E679C960363N202301.csv... (8 MB)
#        -> 490,276 rows in 22.1s
#   [14/22] [esma_only] 8156005A8E679C960363N202301.csv... (8 MB)
#        -> 11,528 rows in 0.4s
#   [15/22] [esma_only] 8156006C66E55C898594N201901.csv... (178 MB)
#        -> 11,528 rows in 0.4s
#   [15/22] [esma_only] 8156006C66E55C898594N201901.csv... (178 MB)
#        -> 198,138 rows in 8.7s
#   [16/22] [esma_only] 815600722FAEE18D6013N201901.csv... (17 MB)
#        -> 198,138 rows in 8.7s
#   [16/22] [esma_only] 815600722FAEE18D6013N201901.csv... (17 MB)
#        -> 23,066 rows in 0.8s
#   [17/22] [esma_only] 815600AA335E51233F89N201901.csv... (74 MB)
#        -> 23,066 rows in 0.8s
#   [17/22] [esma_only] 815600AA335E51233F89N201901.csv... (74 MB)
#        -> 83,682 rows in 3.3s
#   [18/22] [esma_only] 815600B634BB07E05C27N201701.csv... (436 MB)
#        -> 83,682 rows in 3.3s
#   [18/22] [esma_only] 815600B634BB07E05C27N201701.csv... (436 MB)
#        -> 532,702 rows in 22.0s
#   [19/22] [esma_only] 815600BEE9123CD92E12N202201.csv... (100 MB)
#        -> 532,702 rows in 22.0s
#   [19/22] [esma_only] 815600BEE9123CD92E12N202201.csv... (100 MB)
#        -> 111,503 rows in 5.3s
#   [20/22] [esma_only] F1T87K3OQ2OV1UORLH26N202002.csv... (23 MB)
#        -> 111,503 rows in 5.3s
#   [20/22] [esma_only] F1T87K3OQ2OV1UORLH26N202002.csv... (23 MB)
#        -> 33,873 rows in 1.4s
#   [21/22] [esma_only] J4CP7MHCXR8DAQMKIL78N200701.csv... (135 MB)
#        -> 33,873 rows in 1.4s
#   [21/22] [esma_only] J4CP7MHCXR8DAQMKIL78N200701.csv... (135 MB)
#        -> 173,048 rows in 7.1s
#   [22/22] [esma_only] J4CP7MHCXR8DAQMKIL78N200702.csv... (89 MB)
#        -> 173,048 rows in 7.1s
#   [22/22] [esma_only] J4CP7MHCXR8DAQMKIL78N200702.csv... (89 MB)
#        -> 113,569 rows in 4.5s
#
#   ✓ COMPLETE: IT
#     Total rows: 11,029,781
#     Columns: 216
#     File size: 9.24 GB
#     Time: 489.8s
#
# [7/10] Starting NL...
#
# ======================================================================
# PROCESSING: NL
# ======================================================================
# Files to merge: 72
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\NL.csv
#
# Phase 1: Building unified column schema...
#        -> 113,569 rows in 4.5s
#
#   ✓ COMPLETE: IT
#     Total rows: 11,029,781
#     Columns: 216
#     File size: 9.24 GB
#     Time: 489.8s
#
# [7/10] Starting NL...
#
# ======================================================================
# PROCESSING: NL
# ======================================================================
# Files to merge: 72
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\NL.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 217 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/72] [matched] RMBMNL000185100120109.csv... (3993 MB)
#   Unified schema: 217 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/72] [matched] RMBMNL000185100120109.csv... (3993 MB)
#        -> 3,148,198 rows in 144.9s
#   [2/72] [matched] RMBMNL001345100220171.csv... (80 MB)
#        -> 3,148,198 rows in 144.9s
#   [2/72] [matched] RMBMNL001345100220171.csv... (80 MB)
#        -> 65,652 rows in 2.6s
#   [3/72] [matched] RMBMNL001345100320187.csv... (32 MB)
#        -> 65,652 rows in 2.6s
#   [3/72] [matched] RMBMNL001345100320187.csv... (32 MB)
#        -> 28,182 rows in 1.1s
#   [4/72] [ecb_only] RMBMNL000125100120063.csv... (351 MB)
#        -> 28,182 rows in 1.1s
#   [4/72] [ecb_only] RMBMNL000125100120063.csv... (351 MB)
#        -> 300,969 rows in 13.5s
#   [5/72] [ecb_only] RMBMNL000125100220111.csv... (2215 MB)
#        -> 300,969 rows in 13.5s
#   [5/72] [ecb_only] RMBMNL000125100220111.csv... (2215 MB)
#        -> 1,903,914 rows in 87.3s
#   [6/72] [ecb_only] RMBMNL000125100320077.csv... (5362 MB)
#        -> 1,903,914 rows in 87.3s
#   [6/72] [ecb_only] RMBMNL000125100320077.csv... (5362 MB)
#        -> 4,595,898 rows in 208.1s
#   [7/72] [ecb_only] RMBMNL000125100420117.csv... (2362 MB)
#        -> 4,595,898 rows in 208.1s
#   [7/72] [ecb_only] RMBMNL000125100420117.csv... (2362 MB)
#        -> 2,065,361 rows in 95.2s
#   [8/72] [ecb_only] RMBMNL000125100520080.csv... (19810 MB)
#        -> 2,065,361 rows in 95.2s
#   [8/72] [ecb_only] RMBMNL000125100520080.csv... (19810 MB)
#        -> 17,194,000 rows in 743.7s
#   [9/72] [ecb_only] RMBMNL000185100220115.csv... (210 MB)
#        -> 17,194,000 rows in 743.7s
#   [9/72] [ecb_only] RMBMNL000185100220115.csv... (210 MB)
#        -> 173,160 rows in 7.4s
#   [10/72] [ecb_only] RMBMNL000185100320139.csv... (235 MB)
#        -> 173,160 rows in 7.4s
#   [10/72] [ecb_only] RMBMNL000185100320139.csv... (235 MB)
#        -> 194,844 rows in 8.2s
#   [11/72] [esma_only] 2138001WO21Z3B8Y8K20N202101.csv... (81 MB)
#        -> 194,844 rows in 8.2s
#   [11/72] [esma_only] 2138001WO21Z3B8Y8K20N202101.csv... (81 MB)
#        -> 73,277 rows in 3.4s
#   [12/72] [esma_only] 5299008I0TO44SUINZ71N202501.csv... (8 MB)
#        -> 73,277 rows in 3.4s
#   [12/72] [esma_only] 5299008I0TO44SUINZ71N202501.csv... (8 MB)
#        -> 9,013 rows in 0.4s
#   [13/72] [esma_only] 5493003SPEWN841SWG39N201901.csv... (610 MB)
#        -> 9,013 rows in 0.4s
#   [13/72] [esma_only] 5493003SPEWN841SWG39N201901.csv... (610 MB)
#        -> 608,462 rows in 28.9s
#   [14/72] [esma_only] 549300772D1G8JPIUR96N202001.csv... (244 MB)
#        -> 608,462 rows in 28.9s
#   [14/72] [esma_only] 549300772D1G8JPIUR96N202001.csv... (244 MB)
#        -> 245,154 rows in 11.0s
#   [15/72] [esma_only] 549300F2EUS6QS7H4D81N201901.csv... (13 MB)
#        -> 245,154 rows in 11.0s
#   [15/72] [esma_only] 549300F2EUS6QS7H4D81N201901.csv... (13 MB)
#        -> 13,236 rows in 0.6s
#   [16/72] [esma_only] 549300F2EUS6QS7H4D81N201902.csv... (34 MB)
#        -> 13,236 rows in 0.6s
#   [16/72] [esma_only] 549300F2EUS6QS7H4D81N201902.csv... (34 MB)
#        -> 32,805 rows in 1.4s
#   [17/72] [esma_only] 549300F2EUS6QS7H4D81N202001.csv... (37 MB)
#        -> 32,805 rows in 1.4s
#   [17/72] [esma_only] 549300F2EUS6QS7H4D81N202001.csv... (37 MB)
#        -> 36,648 rows in 1.5s
#   [18/72] [esma_only] 549300S7DH0HXAJSVI23N201801.csv... (73 MB)
#        -> 36,648 rows in 1.5s
#   [18/72] [esma_only] 549300S7DH0HXAJSVI23N201801.csv... (73 MB)
#        -> 74,348 rows in 3.5s
#   [19/72] [esma_only] 549300S7DH0HXAJSVI23N201901.csv... (79 MB)
#        -> 74,348 rows in 3.5s
#   [19/72] [esma_only] 549300S7DH0HXAJSVI23N201901.csv... (79 MB)
#        -> 80,959 rows in 3.7s
#   [20/72] [esma_only] 549300S7DH0HXAJSVI23N202101.csv... (121 MB)
#        -> 80,959 rows in 3.7s
#   [20/72] [esma_only] 549300S7DH0HXAJSVI23N202101.csv... (121 MB)
#        -> 127,490 rows in 6.1s
#   [21/72] [esma_only] 549300S7DH0HXAJSVI23N202301.csv... (69 MB)
#        -> 127,490 rows in 6.1s
#   [21/72] [esma_only] 549300S7DH0HXAJSVI23N202301.csv... (69 MB)
#        -> 66,083 rows in 3.2s
#   [22/72] [esma_only] 549300S7DH0HXAJSVI23N202401.csv... (47 MB)
#        -> 66,083 rows in 3.2s
#   [22/72] [esma_only] 549300S7DH0HXAJSVI23N202401.csv... (47 MB)
#        -> 44,986 rows in 2.0s
#   [23/72] [esma_only] 72450018LF4K4XBY1B12N201901.csv... (24 MB)
#        -> 44,986 rows in 2.0s
#   [23/72] [esma_only] 72450018LF4K4XBY1B12N201901.csv... (24 MB)
#        -> 32,858 rows in 1.3s
#   [24/72] [esma_only] 72450018LF4K4XBY1B12N202001.csv... (39 MB)
#        -> 32,858 rows in 1.3s
#   [24/72] [esma_only] 72450018LF4K4XBY1B12N202001.csv... (39 MB)
#        -> 55,066 rows in 2.0s
#   [25/72] [esma_only] 72450018LF4K4XBY1B12N202101.csv... (32 MB)
#        -> 55,066 rows in 2.0s
#   [25/72] [esma_only] 72450018LF4K4XBY1B12N202101.csv... (32 MB)
#        -> 43,481 rows in 1.5s
#   [26/72] [esma_only] 72450018LF4K4XBY1B12N202201.csv... (22 MB)
#        -> 43,481 rows in 1.5s
#   [26/72] [esma_only] 72450018LF4K4XBY1B12N202201.csv... (22 MB)
#        -> 30,280 rows in 1.0s
#   [27/72] [esma_only] 72450018LF4K4XBY1B12N202301.csv... (10 MB)
#        -> 30,280 rows in 1.0s
#   [27/72] [esma_only] 72450018LF4K4XBY1B12N202301.csv... (10 MB)
#        -> 13,307 rows in 0.5s
#   [28/72] [esma_only] 72450018LF4K4XBY1B12N202401.csv... (8 MB)
#        -> 13,307 rows in 0.5s
#   [28/72] [esma_only] 72450018LF4K4XBY1B12N202401.csv... (8 MB)
#        -> 11,442 rows in 0.4s
#   [29/72] [esma_only] 72450018LF4K4XBY1B12N202501.csv... (3 MB)
#        -> 3,873 rows in 0.1s
#   [30/72] [esma_only] 7245002ZUXNOEJ0QPZ44N202101.csv... (59 MB)
#        -> 11,442 rows in 0.4s
#   [29/72] [esma_only] 72450018LF4K4XBY1B12N202501.csv... (3 MB)
#        -> 3,873 rows in 0.1s
#   [30/72] [esma_only] 7245002ZUXNOEJ0QPZ44N202101.csv... (59 MB)
#        -> 63,510 rows in 2.6s
#   [31/72] [esma_only] 7245002ZUXNOEJ0QPZ44N202501.csv... (11 MB)
#        -> 63,510 rows in 2.6s
#   [31/72] [esma_only] 7245002ZUXNOEJ0QPZ44N202501.csv... (11 MB)
#        -> 12,374 rows in 0.6s
#   [32/72] [esma_only] 72450044QJ5PCRWOWA46N202007.csv... (411 MB)
#        -> 12,374 rows in 0.6s
#   [32/72] [esma_only] 72450044QJ5PCRWOWA46N202007.csv... (411 MB)
#        -> 512,698 rows in 22.6s
#   [33/72] [esma_only] 7245006LFTO2U2HODE80N202201.csv... (61 MB)
#        -> 512,698 rows in 22.6s
#   [33/72] [esma_only] 7245006LFTO2U2HODE80N202201.csv... (61 MB)
#        -> 46,041 rows in 2.3s
#   [34/72] [esma_only] 724500A1FNICHSDF2I11N202301.csv... (2410 MB)
#        -> 46,041 rows in 2.3s
#   [34/72] [esma_only] 724500A1FNICHSDF2I11N202301.csv... (2410 MB)
#        -> 2,505,111 rows in 115.9s
#   [35/72] [esma_only] 724500AH42V5X8BCPE49N202101.csv... (171 MB)
#        -> 2,505,111 rows in 115.9s
#   [35/72] [esma_only] 724500AH42V5X8BCPE49N202101.csv... (171 MB)
#        -> 216,730 rows in 9.4s
#   [36/72] [esma_only] 724500BJL5Q2QAAIO690N202401.csv... (13 MB)
#        -> 216,730 rows in 9.4s
#   [36/72] [esma_only] 724500BJL5Q2QAAIO690N202401.csv... (13 MB)
#        -> 12,436 rows in 0.6s
#   [37/72] [esma_only] 724500FJ7SUXFJB7NN36N200601.csv... (23 MB)
#        -> 12,436 rows in 0.6s
#   [37/72] [esma_only] 724500FJ7SUXFJB7NN36N200601.csv... (23 MB)
#        -> 23,260 rows in 1.1s
#   [38/72] [esma_only] 724500ISK5V0VFQS1654N202501.csv... (4 MB)
#        -> 23,260 rows in 1.1s
#   [38/72] [esma_only] 724500ISK5V0VFQS1654N202501.csv... (4 MB)
#        -> 4,760 rows in 0.2s
#   [39/72] [esma_only] 724500KSGL8ZJTV22463N201901.csv... (170 MB)
#        -> 4,760 rows in 0.2s
#   [39/72] [esma_only] 724500KSGL8ZJTV22463N201901.csv... (170 MB)
#        -> 171,154 rows in 8.0s
#   [40/72] [esma_only] 724500O4GUVTGSZEU248N202301.csv... (52 MB)
#        -> 171,154 rows in 8.0s
#   [40/72] [esma_only] 724500O4GUVTGSZEU248N202301.csv... (52 MB)
#        -> 65,150 rows in 2.7s
#   [41/72] [esma_only] 724500O4GUVTGSZEU248N202302.csv... (147 MB)
#        -> 65,150 rows in 2.7s
#   [41/72] [esma_only] 724500O4GUVTGSZEU248N202302.csv... (147 MB)
#        -> 185,633 rows in 8.1s
#   [42/72] [esma_only] 724500O4GUVTGSZEU248N202501.csv... (14 MB)
#        -> 185,633 rows in 8.1s
#   [42/72] [esma_only] 724500O4GUVTGSZEU248N202501.csv... (14 MB)
#        -> 17,788 rows in 0.7s
#   [43/72] [esma_only] 724500T5HC7NI06PEW24N201902.csv... (22 MB)
#        -> 17,788 rows in 0.7s
#   [43/72] [esma_only] 724500T5HC7NI06PEW24N201902.csv... (22 MB)
#        -> 23,635 rows in 1.0s
#   [44/72] [esma_only] 724500T5HC7NI06PEW24N202001.csv... (16 MB)
#        -> 23,635 rows in 1.0s
#   [44/72] [esma_only] 724500T5HC7NI06PEW24N202001.csv... (16 MB)
#        -> 18,186 rows in 0.7s
#   [45/72] [esma_only] 724500T5HC7NI06PEW24N202401.csv... (11 MB)
#        -> 18,186 rows in 0.7s
#   [45/72] [esma_only] 724500T5HC7NI06PEW24N202401.csv... (11 MB)
#        -> 12,176 rows in 0.6s
#   [46/72] [esma_only] 724500VZ11H30K1D6902N201603.csv... (22 MB)
#        -> 12,176 rows in 0.6s
#   [46/72] [esma_only] 724500VZ11H30K1D6902N201603.csv... (22 MB)
#        -> 23,992 rows in 1.1s
#   [47/72] [esma_only] 724500VZ11H30K1D6902N201802.csv... (35 MB)
#        -> 23,992 rows in 1.1s
#   [47/72] [esma_only] 724500VZ11H30K1D6902N201802.csv... (35 MB)
#        -> 38,179 rows in 1.6s
#   [48/72] [esma_only] 724500VZ11H30K1D6902N201804.csv... (84 MB)
#        -> 38,179 rows in 1.6s
#   [48/72] [esma_only] 724500VZ11H30K1D6902N201804.csv... (84 MB)
#        -> 92,133 rows in 4.4s
#   [49/72] [esma_only] 724500VZ11H30K1D6902N201805.csv... (186 MB)
#        -> 92,133 rows in 4.4s
#   [49/72] [esma_only] 724500VZ11H30K1D6902N201805.csv... (186 MB)
#        -> 199,582 rows in 8.9s
#   [50/72] [esma_only] 724500VZ11H30K1D6902N201901.csv... (251 MB)
#        -> 199,582 rows in 8.9s
#   [50/72] [esma_only] 724500VZ11H30K1D6902N201901.csv... (251 MB)
#        -> 274,509 rows in 12.6s
#   [51/72] [esma_only] 724500VZ11H30K1D6902N202001.csv... (173 MB)
#        -> 274,509 rows in 12.6s
#   [51/72] [esma_only] 724500VZ11H30K1D6902N202001.csv... (173 MB)
#        -> 189,301 rows in 8.3s
#   [52/72] [esma_only] 724500VZ11H30K1D6902N202101.csv... (83 MB)
#        -> 189,301 rows in 8.3s
#   [52/72] [esma_only] 724500VZ11H30K1D6902N202101.csv... (83 MB)
#        -> 90,669 rows in 3.9s
#   [53/72] [esma_only] 724500VZ11H30K1D6902N202201.csv... (72 MB)
#        -> 90,669 rows in 3.9s
#   [53/72] [esma_only] 724500VZ11H30K1D6902N202201.csv... (72 MB)
#        -> 79,109 rows in 3.4s
#   [54/72] [esma_only] 724500VZ11H30K1D6902N202301.csv... (55 MB)
#        -> 79,109 rows in 3.4s
#   [54/72] [esma_only] 724500VZ11H30K1D6902N202301.csv... (55 MB)
#        -> 60,362 rows in 2.7s
#   [55/72] [esma_only] 724500XOGMV0BMF6EK71N202001.csv... (12 MB)
#        -> 60,362 rows in 2.7s
#   [55/72] [esma_only] 724500XOGMV0BMF6EK71N202001.csv... (12 MB)
#        -> 9,755 rows in 0.5s
#   [56/72] [esma_only] 724500YGUK3ZCLGPE353N201701.csv... (67 MB)
#        -> 9,755 rows in 0.5s
#   [56/72] [esma_only] 724500YGUK3ZCLGPE353N201701.csv... (67 MB)
#        -> 100,535 rows in 4.0s
#   [57/72] [esma_only] 724500YGUK3ZCLGPE353N201801.csv... (49 MB)
#        -> 100,535 rows in 4.0s
#   [57/72] [esma_only] 724500YGUK3ZCLGPE353N201801.csv... (49 MB)
#        -> 73,501 rows in 2.5s
#   [58/72] [esma_only] 724500YGUK3ZCLGPE353N201901.csv... (46 MB)
#        -> 73,501 rows in 2.5s
#   [58/72] [esma_only] 724500YGUK3ZCLGPE353N201901.csv... (46 MB)
#        -> 69,043 rows in 2.4s
#   [59/72] [esma_only] 724500YGUK3ZCLGPE353N202001.csv... (26 MB)
#        -> 69,043 rows in 2.4s
#   [59/72] [esma_only] 724500YGUK3ZCLGPE353N202001.csv... (26 MB)
#        -> 39,162 rows in 1.3s
#   [60/72] [esma_only] 724500YGUK3ZCLGPE353N202002.csv... (24 MB)
#        -> 39,162 rows in 1.3s
#   [60/72] [esma_only] 724500YGUK3ZCLGPE353N202002.csv... (24 MB)
#        -> 36,160 rows in 1.3s
#   [61/72] [esma_only] 724500YGUK3ZCLGPE353N202102.csv... (27 MB)
#        -> 36,160 rows in 1.3s
#   [61/72] [esma_only] 724500YGUK3ZCLGPE353N202102.csv... (27 MB)
#        -> 41,820 rows in 1.4s
#   [62/72] [esma_only] 724500YGUK3ZCLGPE353N202201.csv... (14 MB)
#        -> 41,820 rows in 1.4s
#   [62/72] [esma_only] 724500YGUK3ZCLGPE353N202201.csv... (14 MB)
#        -> 22,508 rows in 0.9s
#   [63/72] [esma_only] 724500YGUK3ZCLGPE353N202202.csv... (8 MB)
#        -> 22,508 rows in 0.9s
#   [63/72] [esma_only] 724500YGUK3ZCLGPE353N202202.csv... (8 MB)
#        -> 12,232 rows in 0.5s
#   [64/72] [esma_only] 724500YGUK3ZCLGPE353N202301.csv... (14 MB)
#        -> 12,232 rows in 0.5s
#   [64/72] [esma_only] 724500YGUK3ZCLGPE353N202301.csv... (14 MB)
#        -> 22,269 rows in 0.9s
#   [65/72] [esma_only] 8IBZUGJ7JPLH368JE346N201801.csv... (7 MB)
#        -> 22,269 rows in 0.9s
#   [65/72] [esma_only] 8IBZUGJ7JPLH368JE346N201801.csv... (7 MB)
#        -> 6,489 rows in 0.3s
#   [66/72] [esma_only] 8IBZUGJ7JPLH368JE346N201901.csv... (55 MB)
#        -> 6,489 rows in 0.3s
#   [66/72] [esma_only] 8IBZUGJ7JPLH368JE346N201901.csv... (55 MB)
#        -> 53,561 rows in 2.4s
#   [67/72] [esma_only] 8IBZUGJ7JPLH368JE346N202101.csv... (82 MB)
#        -> 53,561 rows in 2.4s
#   [67/72] [esma_only] 8IBZUGJ7JPLH368JE346N202101.csv... (82 MB)
#        -> 79,677 rows in 3.9s
#   [68/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201601.csv... (140 MB)
#        -> 79,677 rows in 3.9s
#   [68/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201601.csv... (140 MB)
#        -> 150,457 rows in 6.7s
#   [69/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201701.csv... (143 MB)
#        -> 150,457 rows in 6.7s
#   [69/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201701.csv... (143 MB)
#        -> 155,447 rows in 6.8s
#   [70/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201801.csv... (24 MB)
#        -> 155,447 rows in 6.8s
#   [70/72] [esma_only] B64D6Y3LBJS4ANNPCU93N201801.csv... (24 MB)
#        -> 26,862 rows in 1.1s
#   [71/72] [esma_only] B64D6Y3LBJS4ANNPCU93N202002.csv... (351 MB)
#        -> 26,862 rows in 1.1s
#   [71/72] [esma_only] B64D6Y3LBJS4ANNPCU93N202002.csv... (351 MB)
#        -> 381,246 rows in 17.2s
#   [72/72] [esma_only] DG3RU1DBUFHT4ZF9WN62N201001.csv... (2434 MB)
#        -> 381,246 rows in 17.2s
#   [72/72] [esma_only] DG3RU1DBUFHT4ZF9WN62N201001.csv... (2434 MB)
#        -> 2,460,253 rows in 120.0s
#
#   ✓ COMPLETE: NL
#     Total rows: 39,952,401
#     Columns: 217
#     File size: 45.37 GB
#     Time: 1784.3s
#
# [8/10] Starting PT...
#
# ======================================================================
# PROCESSING: PT
# ======================================================================
# Files to merge: 15
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\PT.csv
#
# Phase 1: Building unified column schema...
#        -> 2,460,253 rows in 120.0s
#
#   ✓ COMPLETE: NL
#     Total rows: 39,952,401
#     Columns: 217
#     File size: 45.37 GB
#     Time: 1784.3s
#
# [8/10] Starting PT...
#
# ======================================================================
# PROCESSING: PT
# ======================================================================
# Files to merge: 15
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\PT.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 328 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/15] [esma_only] 2138004FIUXU3B2MR537N200801.csv... (8 MB)
#   Unified schema: 328 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/15] [esma_only] 2138004FIUXU3B2MR537N200801.csv... (8 MB)
#        -> 9,804 rows in 0.7s
#   [2/15] [esma_only] 213800LIUKUVD7YK6W32N200701.csv... (9 MB)
#        -> 9,804 rows in 0.7s
#   [2/15] [esma_only] 213800LIUKUVD7YK6W32N200701.csv... (9 MB)
#        -> 12,014 rows in 0.7s
#   [3/15] [esma_only] 213800WQJJDCAN4BCO57N201901.csv... (75 MB)
#        -> 12,014 rows in 0.7s
#   [3/15] [esma_only] 213800WQJJDCAN4BCO57N201901.csv... (75 MB)
#        -> 128,842 rows in 6.8s
#   [4/15] [esma_only] 54930066NQ53X7Z8DO76N200701.csv... (58 MB)
#        -> 128,842 rows in 6.8s
#   [4/15] [esma_only] 54930066NQ53X7Z8DO76N200701.csv... (58 MB)
#        -> 83,785 rows in 5.0s
#   [5/15] [esma_only] 549300ELBHWFMLA2R125N200601.csv... (79 MB)
#        -> 83,785 rows in 5.0s
#   [5/15] [esma_only] 549300ELBHWFMLA2R125N200601.csv... (79 MB)
#        -> 112,245 rows in 6.7s
#   [6/15] [esma_only] 549300W5EE53HVM32O36N200801.csv... (109 MB)
#        -> 112,245 rows in 6.7s
#   [6/15] [esma_only] 549300W5EE53HVM32O36N200801.csv... (109 MB)
#        -> 155,810 rows in 9.4s
#   [7/15] [esma_only] 549300Y8LUK3U2T7BG03N200801.csv... (8 MB)
#        -> 155,810 rows in 9.4s
#   [7/15] [esma_only] 549300Y8LUK3U2T7BG03N200801.csv... (8 MB)
#        -> 11,015 rows in 0.6s
#   [8/15] [esma_only] 549300Y8LUK3U2T7BG03N200802.csv... (13 MB)
#        -> 11,015 rows in 0.6s
#   [8/15] [esma_only] 549300Y8LUK3U2T7BG03N200802.csv... (13 MB)
#        -> 17,169 rows in 0.9s
#   [9/15] [esma_only] 549300Y8LUK3U2T7BG03N200901.csv... (15 MB)
#        -> 17,169 rows in 0.9s
#   [9/15] [esma_only] 549300Y8LUK3U2T7BG03N200901.csv... (15 MB)
#        -> 19,765 rows in 1.1s
#   [10/15] [esma_only] 549300Y8LUK3U2T7BG03N201801.csv... (111 MB)
#        -> 19,765 rows in 1.1s
#   [10/15] [esma_only] 549300Y8LUK3U2T7BG03N201801.csv... (111 MB)
#        -> 141,053 rows in 8.5s
#   [11/15] [esma_only] 549300Y8LUK3U2T7BG03N202501.csv... (13 MB)
#        -> 141,053 rows in 8.5s
#   [11/15] [esma_only] 549300Y8LUK3U2T7BG03N202501.csv... (13 MB)
#        -> 16,987 rows in 1.1s
#   [12/15] [esma_only] 549300YAVKUX02HU6210N200501.csv... (67 MB)
#        -> 16,987 rows in 1.1s
#   [12/15] [esma_only] 549300YAVKUX02HU6210N200501.csv... (67 MB)
#        -> 98,100 rows in 6.2s
#   [13/15] [esma_only] 635400X8LJOEVGKVCU62N202001.csv... (63 MB)
#        -> 98,100 rows in 6.2s
#   [13/15] [esma_only] 635400X8LJOEVGKVCU62N202001.csv... (63 MB)
#        -> 62,118 rows in 4.0s
#   [14/15] [esma_only] 635400X8LJOEVGKVCU62N202201.csv... (36 MB)
#        -> 62,118 rows in 4.0s
#   [14/15] [esma_only] 635400X8LJOEVGKVCU62N202201.csv... (36 MB)
#        -> 34,963 rows in 2.2s
#   [15/15] [esma_only] JU1U6S0DG9YLT7N8ZV32N200501.csv... (31 MB)
#        -> 34,963 rows in 2.2s
#   [15/15] [esma_only] JU1U6S0DG9YLT7N8ZV32N200501.csv... (31 MB)
#        -> 48,840 rows in 2.8s
#
#   ✓ COMPLETE: PT
#     Total rows: 952,510
#     Columns: 328
#     File size: 0.85 GB
#     Time: 57.0s
#
# [9/10] Starting UK...
#
# ======================================================================
# PROCESSING: UK
# ======================================================================
# Files to merge: 8
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\UK.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 213 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/8] [matched] RMBMUK000172100220060.csv... (8518 MB)
#        -> 48,840 rows in 2.8s
#
#   ✓ COMPLETE: PT
#     Total rows: 952,510
#     Columns: 328
#     File size: 0.85 GB
#     Time: 57.0s
#
# [9/10] Starting UK...
#
# ======================================================================
# PROCESSING: UK
# ======================================================================
# Files to merge: 8
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\UK.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 213 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/8] [matched] RMBMUK000172100220060.csv... (8518 MB)
#        -> 13,210,315 rows in 600.9s
#   [2/8] [matched] RMBMUK000203100120065.csv... (5220 MB)
#        -> 13,210,315 rows in 600.9s
#   [2/8] [matched] RMBMUK000203100120065.csv... (5220 MB)
#        -> 5,189,825 rows in 225.5s
#   [3/8] [matched] RMBMUK000209100520063.csv... (8373 MB)
#        -> 5,189,825 rows in 225.5s
#   [3/8] [matched] RMBMUK000209100520063.csv... (8373 MB)
#        -> 7,617,414 rows in 329.3s
#   [4/8] [matched] RMBMUK000551100120075.csv... (1857 MB)
#        -> 7,617,414 rows in 329.3s
#   [4/8] [matched] RMBMUK000551100120075.csv... (1857 MB)
#        -> 2,065,342 rows in 99.6s
#   [5/8] [ecb_only] RMBMUK000064100120061.csv... (4291 MB)
#        -> 2,065,342 rows in 99.6s
#   [5/8] [ecb_only] RMBMUK000064100120061.csv... (4291 MB)
#        -> 4,266,948 rows in 202.9s
#   [6/8] [ecb_only] RMBMUK000113100120082.csv... (16521 MB)
#        -> 4,266,948 rows in 202.9s
#   [6/8] [ecb_only] RMBMUK000113100120082.csv... (16521 MB)
#        -> 17,361,228 rows in 791.7s
#   [7/8] [ecb_only] RMBMUK000172100320068.csv... (6430 MB)
#        -> 17,361,228 rows in 791.7s
#   [7/8] [ecb_only] RMBMUK000172100320068.csv... (6430 MB)
#        -> 10,340,447 rows in 457.2s
#   [8/8] [ecb_only] RMBMUK000172100420082.csv... (4537 MB)
#        -> 10,340,447 rows in 457.2s
#   [8/8] [ecb_only] RMBMUK000172100420082.csv... (4537 MB)
#        -> 7,462,635 rows in 315.9s
#
#   ✓ COMPLETE: UK
#     Total rows: 67,514,154
#     Columns: 213
#     File size: 56.84 GB
#     Time: 3023.2s
#
# [10/10] Starting UNKNOWN...
#
# ======================================================================
# PROCESSING: UNKNOWN
# ======================================================================
# Files to merge: 1
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\UNKNOWN.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 192 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/1] [esma_only] 213800WQJJDCAN4BCO57N202001.csv... (152 MB)
#        -> 7,462,635 rows in 315.9s
#
#   ✓ COMPLETE: UK
#     Total rows: 67,514,154
#     Columns: 213
#     File size: 56.84 GB
#     Time: 3023.2s
#
# [10/10] Starting UNKNOWN...
#
# ======================================================================
# PROCESSING: UNKNOWN
# ======================================================================
# Files to merge: 1
# Output: D:\ECB_ESMA_BY_COUNTRY_ALL\UNKNOWN.csv
#
# Phase 1: Building unified column schema...
#   Unified schema: 192 columns
#
# Phase 2: Merging files (chunked streaming)...
#   [1/1] [esma_only] 213800WQJJDCAN4BCO57N202001.csv... (152 MB)
#        -> 205,991 rows in 7.4s
#
#   ✓ COMPLETE: UNKNOWN
#     Total rows: 205,991
#     Columns: 192
#     File size: 0.15 GB
#     Time: 7.4s
#
# ==========================================================================================
# ALL COUNTRIES PROCESSED
# ==========================================================================================
#
#   New: 9, Skipped: 1, Failed: 0
#        -> 205,991 rows in 7.4s
#
#   ✓ COMPLETE: UNKNOWN
#     Total rows: 205,991
#     Columns: 192
#     File size: 0.15 GB
#     Time: 7.4s
#
# ==========================================================================================
# ALL COUNTRIES PROCESSED
# ==========================================================================================
#
#   New: 9, Skipped: 1, Failed: 0

# %%
# =============================================================================
# CELL 6: Summary Report
# =============================================================================
print("="*90)
print("FINAL SUMMARY REPORT")
print("="*90)
print()

print(f"Total processing time: {overall_elapsed/60:.1f} minutes")
print(f"Output directory: {OUTPUT_DIR}")
print()

# Success summary
print(f"✓ Newly processed: {len(merge_results)} countries")
print(f"⏭️  Skipped (already done): {len(skipped_countries)} countries")
if failed_countries:
    print(f"✗ Failed: {len(failed_countries)} countries")
print()

# Detailed results table
print("-"*90)
print(f"{'Country':<10} {'Files':<8} {'Rows':<15} {'Columns':<10} {'Size (GB)':<12} {'Time (s)':<10}")
print("-"*90)

total_rows_all = 0
total_size_all = 0

for r in merge_results:
    print(f"{r['country']:<10} {r['files_merged']:<8} {r['total_rows']:>12,} {r['columns']:<10} {r['size_gb']:<12.2f} {r['time_seconds']:<10.1f}")
    total_rows_all += r['total_rows']
    total_size_all += r['size_gb']

print("-"*90)
print(f"{'TOTAL':<10} {len(file_index):<8} {total_rows_all:>12,} {'':<10} {total_size_all:<12.2f} {overall_elapsed:<10.1f}")
print()

# Failed countries details
if failed_countries:
    print("\nFAILED COUNTRIES:")
    for f in failed_countries:
        print(f"  {f['country']}: {f['error']}")
    print()

# List output files
print("\nOUTPUT FILES:")
for r in merge_results:
    print(f"  {r['output_path']}")

print()
print(f"Completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ==========================================================================================
# FINAL SUMMARY REPORT
# ==========================================================================================
#
# Total processing time: 214.8 minutes
# Output directory: D:\ECB_ESMA_BY_COUNTRY_ALL
#
# ✓ Newly processed: 9 countries
# ⏭️  Skipped (already done): 1 countries
#
# ------------------------------------------------------------------------------------------
# Country    Files    Rows            Columns    Size (GB)    Time (s)
# ------------------------------------------------------------------------------------------
# DE         15         53,242,506 216        53.73        2293.0
# ES         87         13,545,314 216        12.19        580.6
# FR         30         92,034,390 215        91.68        4443.1
# IE         24          4,849,990 196        4.31         204.0
# IT         22         11,029,781 216        9.24         489.8
# NL         72         39,952,401 217        45.37        1784.3
# PT         15            952,510 328        0.85         57.0
# UK         8          67,514,154 213        56.84        3023.2
# UNKNOWN    1             205,991 192        0.15         7.4
# ------------------------------------------------------------------------------------------
# TOTAL      304       283,327,037            274.36       12885.6
#
#
# OUTPUT FILES:
#   D:\ECB_ESMA_BY_COUNTRY_ALL\DE.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\ES.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\FR.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\IE.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\IT.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\NL.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\PT.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\UK.csv
#   D:\ECB_ESMA_BY_COUNTRY_ALL\UNKNOWN.csv
#
# Completed at: 2025-12-13 02:02:06

# %%
# =============================================================================
# CELL 7: Save Merge Log to JSON
# =============================================================================
import json

log_data = {
    'run_timestamp': datetime.now().isoformat(),
    'input_dir': INPUT_DIR,
    'output_dir': OUTPUT_DIR,
    'total_files_processed': len(file_index),
    'countries_processed': len(merge_results),
    'countries_failed': len(failed_countries),
    'total_rows': total_rows_all,
    'total_size_gb': total_size_all,
    'total_time_seconds': overall_elapsed,
    'results': merge_results,
    'failures': failed_countries,
    'country_stats': {k: dict(v) for k, v in country_stats.items()}
}

log_path = os.path.join(OUTPUT_DIR, 'merge_log.json')
with open(log_path, 'w') as f:
    json.dump(log_data, f, indent=2, default=str)

print(f"Merge log saved to: {log_path}")
# Out:
# Merge log saved to: D:\ECB_ESMA_BY_COUNTRY_ALL\merge_log.json

# %%
# =============================================================================
# CELL 8: Quick Verification of Output Files
# =============================================================================
print("="*90)
print("QUICK VERIFICATION OF OUTPUT FILES")
print("="*90)
print()

# Check each output file
for r in merge_results:
    filepath = r['output_path']
    country = r['country']
    
    if not os.path.exists(filepath):
        print(f"✗ {country}: File not found!")
        continue
    
    # Read sample and check
    df_sample = pd.read_csv(filepath, nrows=1000)
    file_size = os.path.getsize(filepath) / (1024**3)
    
    # Check source distribution
    source_dist = df_sample['source'].value_counts().to_dict() if 'source' in df_sample.columns else {}
    
    # Check column count
    col_count = len(df_sample.columns)
    
    print(f"✓ {country}: {file_size:.2f} GB, {col_count} cols, sources: {source_dist}")

print()
print("Verification complete!")
# Out:
# ==========================================================================================
# QUICK VERIFICATION OF OUTPUT FILES
# ==========================================================================================
#
# ✓ DE: 53.73 GB, 216 cols, sources: {'ECB': 1000}
# ✓ ES: 12.19 GB, 216 cols, sources: {'ECB': 1000}
# ✓ FR: 91.68 GB, 215 cols, sources: {'ECB': 1000}
# ✓ IE: 4.31 GB, 196 cols, sources: {'ESMA': 1000}
# ✓ IT: 9.24 GB, 216 cols, sources: {'ECB': 1000}
# ✓ NL: 45.37 GB, 217 cols, sources: {'ECB': 1000}
# ✓ NL: 45.37 GB, 217 cols, sources: {'ECB': 1000}
# ✓ PT: 0.85 GB, 328 cols, sources: {'ESMA': 1000}
# ✓ PT: 0.85 GB, 328 cols, sources: {'ESMA': 1000}
# ✓ UK: 56.84 GB, 213 cols, sources: {'ECB': 1000}
# ✓ UNKNOWN: 0.15 GB, 192 cols, sources: {'ESMA': 1000}
#
# Verification complete!
# ✓ UK: 56.84 GB, 213 cols, sources: {'ECB': 1000}
# ✓ UNKNOWN: 0.15 GB, 192 cols, sources: {'ESMA': 1000}
#
# Verification complete!
